# %% [markdown]
# # Context Search
#
# It is possible that the problem of predicting 10 Baggers cannot be solved by more advanced machine learning.
#
# If a person had travelled in time from the future, this problem would be solved by asking him or her. But supposed that person were not interested in the stock market and we cannot ask him directly "Which stocks have appreciated in price more than 10 times from date X1 to date X2?" What, then, are the general questions we should ask him which would increase the probability of predicting 10 Baggers?
#
# "In the future, do people still drive gas-powered cars or electric cars?"
#
# "In the future, are there a lot of robots or flying drones? What kind of purposes do they serve?"
#
# "In the future, is cancer (or Alzheimer) a treatable disease?"
#
# and so on....

# %%
import quandl  # Access to Sharadar Core US Equities Bundle
api_key = '7B87ndLPJbCDzpNHosH3'

import math
import platform
import matplotlib
import matplotlib.pyplot as plt
from pylab import rcParams
import numpy as np
from sklearn import linear_model  # package for logistic regression (not using GPU)
import torch
import pandas as pd
from IPython.display import display
import time

from utils import *

from datetime import date, datetime, time, timedelta


print("Python version: ", platform.python_version())
print("Pytorch version: {}".format(torch.__version__))
# Out:
# Python version:  3.6.6
# Pytorch version: 1.1.0

# %%
stocks = pd.read_csv("stock_tickers_sorted.cvs")

display(stocks['industry'].describe())
display(stocks['industry'].unique())
# Out:
# count             10207
# unique              178
# top       Biotechnology
# freq                828
# Name: industry, dtype: object
# array(['Diagnostics & Research', 'Aluminum', 'Biotechnology',
#        'Medical Care', 'Asset Management',
#        'Education & Training Services', 'Conglomerates', 'None',
#        'Airlines', 'Aerospace & Defense', 'Airports & Air Services',
#        'Insurance - Life', 'Rental & Leasing Services',
#        'Banks - Regional', 'Semiconductors',
#        'Building Products & Equipment', 'Specialty Retail', 'Leisure',
#        'Consumer Electronics', 'REIT - Diversified', 'Gold',
#        'Oil & Gas E&P', 'Electrical Equipment & Parts',
#        'Specialty Industrial Machinery', 'Drug Manufacturers - General',
#        'Medical Distribution', 'Health Information Services',
#        'Specialty Chemicals', 'Beverages - Brewers',
#        'Auto & Truck Dealerships', 'Engineering & Construction',
#        'Uranium', 'Communication Equipment', 'Industrial Distribution',
#        'Insurance - Specialty', 'Specialty Business Services',
#        'Medical Devices', 'REIT - Mortgage', 'Telecom Services',
#        'Capital Markets', 'Paper & Paper Products',
#        'Infrastructure Operations', 'Healthcare Plans',
#        'Recreational Vehicles',
#        'Drug Manufacturers - Specialty & Generic', 'REIT - Residential',
#        'Software - Application', 'Business Equipment & Supplies',
#        'Credit Services', 'Banks - Regional - US',
#        'Insurance - Diversified', 'Medical Care Facilities', 'Coal',
#        'Software - Infrastructure', 'Medical Instruments & Supplies',
#        'Oil & Gas Midstream', 'Semiconductor Equipment & Materials',
#        'Real Estate Services', 'Broadcasting',
#        'Information Technology Services', 'Publishing',
#        'Building Materials', 'Consulting Services',
#        'Household & Personal Products', 'Auto Parts', 'REIT - Retail',
#        'Pollution & Treatment Controls', 'Utilities - Regulated Electric',
#        'Farm Products', 'Other Industrial Metals & Mining',
#        'Staffing & Employment Services', 'Waste Management',
#        'Security & Protection Services', 'Packaged Foods',
#        'Drug Manufacturers - Major', 'Oil & Gas Integrated',
#        'Electronic Components', 'Apparel Retail',
#        'Packaging & Containers', 'Utilities - Diversified',
#        'Health Care Plans', 'Electronics & Computer Distribution',
#        'Insurance - Property & Casualty', 'Silver',
#        'Farm & Heavy Construction Machinery', 'Gambling',
#        'Agricultural Inputs', 'Insurance - Reinsurance',
#        'REIT - Hotel & Motel', 'Textile Manufacturing',
#        'Integrated Freight & Logistics', 'Insurance Brokers',
#        'Beverages - Non-Alcoholic', 'Steel', 'Discount Stores',
#        'Oil & Gas Refining & Marketing', 'Business Services',
#        'Computer Hardware', 'Advertising Agencies',
#        'Oil & Gas Equipment & Services', 'Entertainment',
#        'Travel Services', 'REIT - Specialty',
#        'Furnishings, Fixtures & Appliances', 'Internet Retail',
#        'Savings & Cooperative Banks', 'Food Distribution',
#        'Internet Content & Information', 'Chemicals',
#        'Real Estate - Diversified', 'Utilities - Regulated Gas',
#        'Utilities - Renewable', 'Trucking', 'Restaurants',
#        'Metal Fabrication', 'Grocery Stores', 'REIT - Office',
#        'Thermal Coal', 'Railroads', 'Real Estate - Development',
#        'Oil & Gas Drilling', 'Utilities - Regulated Water',
#        'Resorts & Casinos', 'Beverages - Wineries & Distilleries',
#        'Mortgage Finance', 'Farm & Construction Equipment',
#        'Utilities - Independent Power Producers',
#        'Diversified Industrials', 'Electronic Gaming & Multimedia',
#        'Industrial Metals & Minerals', 'Other Precious Metals & Mining',
#        'Residential Construction', 'Scientific & Technical Instruments',
#        'Banks - Global', 'Marine Shipping', 'Banks - Diversified',
#        'Lumber & Wood Production', 'Tools & Accessories', 'Furnishings',
#        'Lodging', 'Personal Services', 'Luxury Goods',
#        'Auto Manufacturers', 'Department Stores',
#        'Footwear & Accessories', 'Tobacco', 'Apparel Stores',
#        'Financial Exchanges', 'REIT - Healthcare Facilities',
#        'Long-Term Care Facilities', 'Pharmaceutical Retailers',
#        'Financial Data & Stock Exchanges', 'Broadcasting - Radio',
#        'REIT - Industrial', 'Apparel Manufacturing', 'Specialty Finance',
#        'Computer Systems', 'Solar', 'Broadcasting - TV',
#        'Shipping & Ports', 'Staffing & Outsourcing Services',
#        'Business Equipment', 'Copper', 'Home Improvement Stores',
#        'Real Estate - General', 'Data Storage', 'Home Improvement Retail',
#        'Confectioners', 'Media - Diversified', 'Marketing Services',
#        'Financial Conglomerates', 'Pay TV', 'Home Furnishings & Fixtures',
#        'Semiconductor Memory', 'Beverages - Soft Drinks',
#        'Banks - Regional - Latin America', 'Coking Coal',
#        'Integrated Shipping & Logistics'], dtype=object)

# %%
industries = stocks['industry'].value_counts()
sectors = industries.to_frame(name="num")

counts = []
ratios = []

for industry, num in industries.items():
    
    num_10baggers = len(stocks[(stocks['industry']==industry) & (stocks['10bagger']==1)].index)
    
    counts.append(num_10baggers)
    ratios.append(num_10baggers/num)

    print("{}:  {} tickers  {} 10baggers ({:.3f})".format(industry, num, num_10baggers, num_10baggers/num))
# Out:
# Biotechnology:  828 tickers  43 10baggers (0.052)
# Banks - Regional:  793 tickers  12 10baggers (0.015)
# None:  480 tickers  8 10baggers (0.017)
# Software - Application:  411 tickers  30 10baggers (0.073)
# Oil & Gas E&P:  279 tickers  4 10baggers (0.014)
# Medical Devices:  240 tickers  13 10baggers (0.054)
# Communication Equipment:  199 tickers  9 10baggers (0.045)
# Semiconductors:  175 tickers  21 10baggers (0.120)
# Asset Management:  169 tickers  3 10baggers (0.018)
# Oil & Gas Midstream:  169 tickers  2 10baggers (0.012)
# Telecom Services:  161 tickers  6 10baggers (0.037)
# REIT - Mortgage:  161 tickers  4 10baggers (0.025)
# Conglomerates:  148 tickers  0 10baggers (0.000)
# Specialty Business Services:  136 tickers  7 10baggers (0.051)
# Diagnostics & Research:  136 tickers  9 10baggers (0.066)
# Information Technology Services:  132 tickers  8 10baggers (0.061)
# Specialty Industrial Machinery:  127 tickers  11 10baggers (0.087)
# Utilities - Regulated Electric:  123 tickers  0 10baggers (0.000)
# Insurance - Property & Casualty:  121 tickers  3 10baggers (0.025)
# Oil & Gas Equipment & Services:  116 tickers  2 10baggers (0.017)
# Packaged Foods:  109 tickers  9 10baggers (0.083)
# Specialty Chemicals:  108 tickers  17 10baggers (0.157)
# Credit Services:  103 tickers  11 10baggers (0.107)
# Banks - Regional - US:  99 tickers  1 10baggers (0.010)
# Specialty Retail:  98 tickers  9 10baggers (0.092)
# Capital Markets:  98 tickers  1 10baggers (0.010)
# Software - Infrastructure:  96 tickers  9 10baggers (0.094)
# Drug Manufacturers - Specialty & Generic:  96 tickers  2 10baggers (0.021)
# Aerospace & Defense:  96 tickers  11 10baggers (0.115)
# Restaurants:  94 tickers  8 10baggers (0.085)
# Leisure:  91 tickers  5 10baggers (0.055)
# Internet Content & Information:  89 tickers  4 10baggers (0.045)
# Medical Care Facilities:  87 tickers  4 10baggers (0.046)
# Auto Parts:  86 tickers  16 10baggers (0.186)
# REIT - Retail:  84 tickers  1 10baggers (0.012)
# Gold:  80 tickers  1 10baggers (0.013)
# Scientific & Technical Instruments:  78 tickers  6 10baggers (0.077)
# Banks - Diversified:  76 tickers  0 10baggers (0.000)
# REIT - Diversified:  76 tickers  1 10baggers (0.013)
# Electronic Components:  74 tickers  8 10baggers (0.108)
# Real Estate Services:  73 tickers  5 10baggers (0.068)
# Other Industrial Metals & Mining:  71 tickers  1 10baggers (0.014)
# Entertainment:  71 tickers  5 10baggers (0.070)
# Engineering & Construction:  68 tickers  3 10baggers (0.044)
# Apparel Retail:  67 tickers  4 10baggers (0.060)
# Medical Instruments & Supplies:  64 tickers  12 10baggers (0.188)
# REIT - Office:  63 tickers  1 10baggers (0.016)
# Advertising Agencies:  61 tickers  2 10baggers (0.033)
# Insurance - Life:  60 tickers  5 10baggers (0.083)
# REIT - Industrial:  60 tickers  3 10baggers (0.050)
# REIT - Hotel & Motel:  60 tickers  1 10baggers (0.017)
# Marine Shipping:  59 tickers  0 10baggers (0.000)
# Household & Personal Products:  58 tickers  3 10baggers (0.052)
# Electrical Equipment & Parts:  58 tickers  1 10baggers (0.017)
# Education & Training Services:  55 tickers  2 10baggers (0.036)
# Computer Hardware:  54 tickers  3 10baggers (0.056)
# Semiconductor Equipment & Materials:  54 tickers  13 10baggers (0.241)
# Broadcasting:  50 tickers  11 10baggers (0.220)
# REIT - Residential:  49 tickers  1 10baggers (0.020)
# Staffing & Employment Services:  46 tickers  4 10baggers (0.087)
# Residential Construction:  45 tickers  1 10baggers (0.022)
# Consulting Services:  44 tickers  1 10baggers (0.023)
# Apparel Manufacturing:  44 tickers  4 10baggers (0.091)
# Chemicals:  43 tickers  3 10baggers (0.070)
# Resorts & Casinos:  42 tickers  4 10baggers (0.095)
# Rental & Leasing Services:  42 tickers  4 10baggers (0.095)
# Industrial Distribution:  41 tickers  4 10baggers (0.098)
# Oil & Gas Refining & Marketing:  41 tickers  3 10baggers (0.073)
# Oil & Gas Drilling:  40 tickers  0 10baggers (0.000)
# Steel:  39 tickers  1 10baggers (0.026)
# Waste Management:  38 tickers  1 10baggers (0.026)
# Building Products & Equipment:  37 tickers  5 10baggers (0.135)
# Packaging & Containers:  37 tickers  1 10baggers (0.027)
# Health Information Services:  37 tickers  3 10baggers (0.081)
# Farm Products:  35 tickers  0 10baggers (0.000)
# Building Materials:  34 tickers  1 10baggers (0.029)
# Utilities - Diversified:  34 tickers  0 10baggers (0.000)
# Agricultural Inputs:  33 tickers  0 10baggers (0.000)
# Airlines:  33 tickers  5 10baggers (0.152)
# Internet Retail:  32 tickers  5 10baggers (0.156)
# Utilities - Regulated Gas:  29 tickers  0 10baggers (0.000)
# Coal:  28 tickers  0 10baggers (0.000)
# Business Equipment & Supplies:  28 tickers  1 10baggers (0.036)
# Oil & Gas Integrated:  27 tickers  0 10baggers (0.000)
# Consumer Electronics:  27 tickers  4 10baggers (0.148)
# Trucking:  27 tickers  3 10baggers (0.111)
# Insurance - Diversified:  26 tickers  0 10baggers (0.000)
# Personal Services:  26 tickers  1 10baggers (0.038)
# Insurance - Specialty:  26 tickers  2 10baggers (0.077)
# Security & Protection Services:  26 tickers  1 10baggers (0.038)
# Tools & Accessories:  25 tickers  1 10baggers (0.040)
# Beverages - Wineries & Distilleries:  25 tickers  2 10baggers (0.080)
# Business Services:  24 tickers  0 10baggers (0.000)
# Farm & Heavy Construction Machinery:  24 tickers  2 10baggers (0.083)
# Recreational Vehicles:  24 tickers  2 10baggers (0.083)
# Publishing:  24 tickers  0 10baggers (0.000)
# Medical Distribution:  24 tickers  0 10baggers (0.000)
# Paper & Paper Products:  24 tickers  6 10baggers (0.250)
# REIT - Healthcare Facilities:  23 tickers  0 10baggers (0.000)
# Insurance - Reinsurance:  23 tickers  0 10baggers (0.000)
# Furnishings, Fixtures & Appliances:  23 tickers  4 10baggers (0.174)
# Railroads:  22 tickers  2 10baggers (0.091)
# Grocery Stores:  22 tickers  0 10baggers (0.000)
# Utilities - Regulated Water:  21 tickers  1 10baggers (0.048)
# REIT - Specialty:  21 tickers  3 10baggers (0.143)
# Integrated Freight & Logistics:  20 tickers  3 10baggers (0.150)
# Healthcare Plans:  19 tickers  6 10baggers (0.316)
# Travel Services:  19 tickers  2 10baggers (0.105)
# Footwear & Accessories:  19 tickers  4 10baggers (0.211)
# Auto & Truck Dealerships:  19 tickers  3 10baggers (0.158)
# Mortgage Finance:  19 tickers  3 10baggers (0.158)
# Pollution & Treatment Controls:  19 tickers  0 10baggers (0.000)
# Solar:  19 tickers  0 10baggers (0.000)
# Auto Manufacturers:  19 tickers  3 10baggers (0.158)
# Beverages - Non-Alcoholic:  19 tickers  1 10baggers (0.053)
# Banks - Global:  18 tickers  0 10baggers (0.000)
# Electronics & Computer Distribution:  18 tickers  1 10baggers (0.056)
# Drug Manufacturers - General:  18 tickers  1 10baggers (0.056)
# Discount Stores:  17 tickers  1 10baggers (0.059)
# Insurance Brokers:  17 tickers  2 10baggers (0.118)
# Food Distribution:  17 tickers  1 10baggers (0.059)
# Metal Fabrication:  16 tickers  0 10baggers (0.000)
# Industrial Metals & Minerals:  16 tickers  0 10baggers (0.000)
# Pharmaceutical Retailers:  16 tickers  0 10baggers (0.000)
# Lodging:  15 tickers  2 10baggers (0.133)
# Luxury Goods:  14 tickers  2 10baggers (0.143)
# Airports & Air Services:  14 tickers  2 10baggers (0.143)
# Tobacco:  14 tickers  0 10baggers (0.000)
# Electronic Gaming & Multimedia:  14 tickers  3 10baggers (0.214)
# Department Stores:  13 tickers  1 10baggers (0.077)
# Diversified Industrials:  13 tickers  0 10baggers (0.000)
# Aluminum:  12 tickers  0 10baggers (0.000)
# Gambling:  12 tickers  0 10baggers (0.000)
# Shipping & Ports:  11 tickers  0 10baggers (0.000)
# Savings & Cooperative Banks:  11 tickers  0 10baggers (0.000)
# Utilities - Renewable:  10 tickers  0 10baggers (0.000)
# Real Estate - Diversified:  10 tickers  1 10baggers (0.100)
# Uranium:  10 tickers  0 10baggers (0.000)
# Beverages - Brewers:  10 tickers  2 10baggers (0.200)
# Financial Data & Stock Exchanges:  9 tickers  3 10baggers (0.333)
# Utilities - Independent Power Producers:  9 tickers  0 10baggers (0.000)
# Silver:  9 tickers  0 10baggers (0.000)
# Home Improvement Retail:  8 tickers  0 10baggers (0.000)
# Real Estate - Development:  8 tickers  1 10baggers (0.125)
# Real Estate - General:  7 tickers  0 10baggers (0.000)
# Thermal Coal:  7 tickers  0 10baggers (0.000)
# Furnishings:  7 tickers  0 10baggers (0.000)
# Confectioners:  7 tickers  0 10baggers (0.000)
# Lumber & Wood Production:  7 tickers  0 10baggers (0.000)
# Drug Manufacturers - Major:  6 tickers  0 10baggers (0.000)
# Textile Manufacturing:  6 tickers  1 10baggers (0.167)
# Specialty Finance:  6 tickers  0 10baggers (0.000)
# Medical Care:  6 tickers  0 10baggers (0.000)
# Other Precious Metals & Mining:  5 tickers  0 10baggers (0.000)
# Broadcasting - TV:  5 tickers  0 10baggers (0.000)
# Computer Systems:  5 tickers  1 10baggers (0.200)
# Media - Diversified:  5 tickers  0 10baggers (0.000)
# Pay TV:  4 tickers  0 10baggers (0.000)
# Copper:  4 tickers  0 10baggers (0.000)
# Semiconductor Memory:  3 tickers  0 10baggers (0.000)
# Apparel Stores:  3 tickers  0 10baggers (0.000)
# Financial Conglomerates:  3 tickers  0 10baggers (0.000)
# Business Equipment:  3 tickers  0 10baggers (0.000)
# Long-Term Care Facilities:  3 tickers  0 10baggers (0.000)
# Broadcasting - Radio:  2 tickers  0 10baggers (0.000)
# Farm & Construction Equipment:  2 tickers  0 10baggers (0.000)
# Home Improvement Stores:  2 tickers  0 10baggers (0.000)
# Health Care Plans:  2 tickers  1 10baggers (0.500)
# Staffing & Outsourcing Services:  2 tickers  0 10baggers (0.000)
# Marketing Services:  2 tickers  0 10baggers (0.000)
# Home Furnishings & Fixtures:  2 tickers  0 10baggers (0.000)
# Data Storage:  2 tickers  0 10baggers (0.000)
# Beverages - Soft Drinks:  1 tickers  0 10baggers (0.000)
# Integrated Shipping & Logistics:  1 tickers  0 10baggers (0.000)
# Financial Exchanges:  1 tickers  0 10baggers (0.000)
# Infrastructure Operations:  1 tickers  0 10baggers (0.000)
# Banks - Regional - Latin America:  1 tickers  0 10baggers (0.000)
# Coking Coal:  1 tickers  0 10baggers (0.000)

# %%
stocks[(stocks['industry']=='Electronic Gaming & Multimedia') & (stocks['10bagger']==1)]
# Out:
#      ticker  appreciation  10bagger table  permaticker  \
# 3981   GLUU     23.782609      True   SEP       194438
# 4114   GRVY     23.344203      True   SEP       189912
# 9255   TTWO     16.702655      True   SEP       197239
#
#                                    name exchange isdelisted  category  \
# 3981                     Glu Mobile Inc   NASDAQ          N  Domestic
# 4114                     GRAVITY Co Ltd   NASDAQ          N       ADR
# 9255  Take Two Interactive Software Inc   NASDAQ          N  Domestic
#
#                    cusips  ...  currency           location lastupdated  \
# 3981            379890106  ...       USD  California; U.S.A  2020-01-14
# 4114  38911N206 38911N107  ...       USD  Republic Of Korea  2020-01-14
# 9255            874054109  ...       USD    New York; U.S.A  2020-01-14
#
#       firstadded firstpricedate lastpricedate firstquarter lastquarter  \
# 3981  2014-10-28     2007-03-22    2020-01-14   2005-12-31  2019-09-30
# 4114  2016-02-03     2005-02-08    2020-01-14   2002-12-31  2018-12-31
# 9255  2015-03-20     1997-04-15    2020-01-14   1996-12-31  2019-09-30
#
#                                              secfilings  \
# 3981  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 4114  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 9255  https://www.sec.gov/cgi-bin/browse-edgar?actio...
#
#                     companysite
# 3981         http://www.glu.com
# 4114   http://www.gravity.co.kr
# 9255  http://www.take2games.com
#
# [3 rows x 30 columns]

# %%
sectors['num_10baggers'] = counts
sectors['ratio'] = ratios
sectors.index.name = 'industry'

sectors
# Out:
#                                   num  num_10baggers     ratio
# industry
# Biotechnology                     828             43  0.051932
# Banks - Regional                  793             12  0.015132
# None                              480              8  0.016667
# Software - Application            411             30  0.072993
# Oil & Gas E&P                     279              4  0.014337
# ...                               ...            ...       ...
# Integrated Shipping & Logistics     1              0  0.000000
# Financial Exchanges                 1              0  0.000000
# Infrastructure Operations           1              0  0.000000
# Banks - Regional - Latin America    1              0  0.000000
# Coking Coal                         1              0  0.000000
#
# [178 rows x 3 columns]

# %%
sectors.to_csv(r'sectors.csv', header=True)
