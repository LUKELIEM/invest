# %% [markdown]
# # Portfolio Strategy - Baseline Model
#
# We will implement three portfolio strategies:
#
# 1. Shotgun then Prune
# 2. Prune Losers; Reinvest in Winners
# 3. Prune Losers; Reinvest in Winners and Newbies
#
# <u>Strategy One - Shotgun then Prune </u>
#
# **First sampling period (3-1-2009 to 12-31-2010)**
#
# Divide cash (e.g. $10 million) evenly into N_1 (e.g. 100) tickers. Tickers are selected though random selection from an unranked prospect list from the Baseline Algorithm.
#
# **Subsequent sampling period (e.g. 3-1-2009 to 12-31-2011)**
#
# Check tickers in the portfolio against the new prospect list. A ticker that is still on the list is considered a "winner". Tickers not on the list are "Losers" and are liquidated to raise cash.
#
# We repeat this process until the last sampling period (3-1-2009 to 12-31-2018).
#
# **Final Tally**
#
# Tally up the investment gain by calculating the value of the portfolio (cash + stocks) on 3-31-2019.
#
#
# <u>Strategy Two - Prune Losers; Reinvest in Winners</u>
#
# **First sampling period (3-1-2009 to 12-31-2010)**
#
# Same as Strategy One.
#
# **Subsequent sampling period (e.g. 3-1-2009 to 12-31-2011)**
#
# Cash raised by selling the Losers is reinvested evenly into the Winners.
#
#
# <u>Strategy Three - Prune Losers; Reinvest in Winners and Newbies</u>
#
# **First sampling period (3-1-2009 to 12-31-2010)**
#
# Same as Strategy One.
#
# **Subsequent sampling period (e.g. 3-1-2009 to 12-31-2011)**
#
# Cash raised by selling the Losers is invested in new tickers selected from the new prospect list. Investment per ticker is the lesser of Available_Cash/N_new or 1e7/N_2, where N_new is the number of new tickers and N_2 is the number of tickers in the 2nd sampling period (e.g. 90).
#
# If there is still cash left over after investing in these new tickers, it is reinvested evenly into the Winners.
#
# <u>Benchmark against S&P (Jan 2011 - Mar 2019)</u>
#
# The cumulative returns of these strategies are compared against the following S&P 500 returns over the period of Jan 2011 - Mar 2019:
#
# * Total S&P 500 Return -	118.613%
# * Annualized S&P 500 Return - 10.051%
# * Total S&P 500 Return (Dividends Reinvested)	- 157.353%
# * Annualized S&P 500 Return (Dividends Reinvested) - 12.271%

# %%
import quandl  # Access to Sharadar Core US Equities Bundle
api_key = '7B87ndLPJbCDzpNHosH3'

import math
import platform

from pylab import rcParams
import numpy as np
from sklearn import linear_model  # package for logistic regression (not using GPU)
import torch
import pandas as pd
from IPython.display import display
import time
import pickle
import random

from utils import *

from datetime import date, datetime, time, timedelta

import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print("Python version: ", platform.python_version())
print("Pytorch version: {}".format(torch.__version__))
# Out:
# Python version:  3.6.6
# Pytorch version: 1.1.0

# %% [markdown]
# ## Import Stock Price History

# %%
stockprices = pd.read_csv("../datasets/sharader/stock_price_history.cvs")
prices = stockprices.set_index('date')

# %%
# Files containing active tickers in the sampling periods
predict_filenames = ['predicts_lin_int_12-31-2010.csv',
              'predicts_lin_int_12-31-2011.csv',
              'predicts_lin_int_12-31-2012.csv',
              'predicts_lin_int_12-31-2013.csv',
              'predicts_lin_int_12-31-2014.csv',
              'predicts_lin_int_12-31-2015.csv',
              'predicts_lin_int_12-31-2016.csv',
              'predicts_lin_int_12-31-2017.csv',
              'predicts_lin_int_12-31-2018.csv'
             ]

# End of sampling period
sampling_end_dates = [
    '2010-12-31',
    '2011-12-30',
    '2012-12-31',
    '2013-12-31',
    '2014-12-31',
    '2015-12-31',
    '2016-12-30',
    '2017-12-29',    
    '2018-12-31'
]

# First January following end of sampling period when portfolio is rebalanced (bought and sold)
rebalance_periods = [
    ('2011-01-03','2011-01-31'),
    ('2012-01-03','2012-01-31'),
    ('2013-01-02','2013-01-31'),
    ('2014-01-02','2014-01-31'),
    ('2015-01-02','2015-01-31'),
    ('2016-01-04','2016-01-31'),
    ('2017-01-03','2017-01-31'),
    ('2018-01-02','2018-01-31'),
    ('2019-01-02','2019-01-31')
]

# End of sampling periods
end_dates = [
    '2010-12-31',
    '2011-12-30',
    '2012-12-31',
    '2013-12-31',
    '2014-12-31',
    '2015-12-31',
    '2016-12-30',
    '2017-12-29',    
    '2018-12-31'
]

# For Strategy One, only the first item is used
portfolio_sizes = [
    100,
    90,
    80,
    70,
    60,
    50,
    40,
    30,
    20
]

START = 1e7 # Start the portfolio with $10M

# the date where the final value of the portfolio is tallied
target_date = '2019-03-29'

# %% [markdown]
# ## Import Prospect Lists (Baseline Linear Interpolation)

# %%
prospects = {}

for date, predict_filename, rebalance_period in zip(sampling_end_dates, predict_filenames, rebalance_periods):
    
    # Get prospect lists for 10 Baggers
    predicts = pd.read_csv("../datasets/sharader/"+predict_filename, index_col=0).set_index('ticker')
    prospects[date] = predicts[predicts['10bagger'] == True]
    
    display(prospects[date])
    
    for ticker in prospects[date].index:
        
        # Determine if ticker has delisted during buy period (First Jan following end of sampling period)
        start, end = rebalance_period
        delist = prices[ticker].loc[start:end].isnull().values.any()
        
        # Remove delisted ticker from prospect list
        if delist:
            print('Remove delist: {}'.format(ticker))
            prospects[date] = prospects[date].drop(index=ticker)
# Out:
#         appreciation  10bagger
# ticker
# A          13.475510      True
# AAI        11.506250      True
# AAL        17.796318      True
# AAME       13.032376      True
# AAPL       15.679507      True
# ...              ...       ...
# ZPLSQ      23.008969      True
# ZQKSQ      22.847138      True
# ZUMZ       15.342757      True
# ZYTO       50.520179      True
# ZZ         14.624600      True
#
# [1792 rows x 2 columns]
# Remove delist: AEZ
# Remove delist: ARTG
# Remove delist: BDLN
# Remove delist: BELM
# Remove delist: BEZ
# Remove delist: CLZR
# Remove delist: CTV1
# Remove delist: DDRX
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: KEI
# Remove delist: POLGA
# Remove delist: PPKZ
# Remove delist: ROAC
# Remove delist: SSCCQ
# Remove delist: TTES
#         appreciation  10bagger
# ticker
# AAPL       13.847328      True
# ABCO       15.749645      True
# ABCP       18.254394      True
# ABEV       13.989380      True
# ABG        25.681838      True
# ...              ...       ...
# ZNH        10.227668      True
# ZOLL       15.304536      True
# ZPCM       42.870039      True
# ZQKSQ      10.048260      True
# ZUMZ       10.714471      True
#
# [907 rows x 2 columns]
# Remove delist: AEZ
# Remove delist: BDLN
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: CALP
# Remove delist: CLZR
# Remove delist: CRFT
# Remove delist: DDRX
# Remove delist: HS
# Remove delist: HTLLQ
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: KEI
# Remove delist: MSSR
# Remove delist: NAVI1
# Remove delist: PNS
# Remove delist: PPKZ
# Remove delist: RNOW
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SFN1
# Remove delist: SNIC
# Remove delist: SSCCQ
# Remove delist: TRXBQ
# Remove delist: VRUS
# Remove delist: ZARLF
#         appreciation  10bagger
# ticker
# AAL        12.741304      True
# AAME       11.125020      True
# AAPL       14.281838      True
# ABCO       15.410088      True
# ABCP       11.932293      True
# ...              ...       ...
# YVR        23.323975      True
# ZAGG       12.920747      True
# ZARLF      22.222222      True
# ZIOP       13.776107      True
# ZPCM       21.376964      True
#
# [769 rows x 2 columns]
# Remove delist: AEA
# Remove delist: AEZ
# Remove delist: BDLN
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: CALP
# Remove delist: CBOU
# Remove delist: CHRS1
# Remove delist: CLSP
# Remove delist: CLZR
# Remove delist: CPWM
# Remove delist: CPX
# Remove delist: DDRX
# Remove delist: DEIX
# Remove delist: DTG
# Remove delist: FSII
# Remove delist: HDLM
# Remove delist: HTLLQ
# Remove delist: IGATY
# Remove delist: INHX
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: KEI
# Remove delist: KNXA
# Remove delist: LCRY
# Remove delist: LMLP1
# Remove delist: NAVI1
# Remove delist: PPKZ
# Remove delist: PXPLY
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SFN1
# Remove delist: SHF
# Remove delist: SNIC
# Remove delist: SRZ
# Remove delist: SSCCQ
# Remove delist: TPCG
# Remove delist: TRXBQ
# Remove delist: VRUS
# Remove delist: ZARLF
#         appreciation  10bagger
# ticker
# AAL        20.234366      True
# AAMC      367.159269      True
# AAME       12.305200      True
# AAPL       12.219286      True
# ABCO       17.306016      True
# ...              ...       ...
# ZARLF      22.222222      True
# ZIOP       11.662754      True
# ZLC        28.279770      True
# ZPCM       27.590793      True
# ZQKSQ      16.846109      True
#
# [959 rows x 2 columns]
# Remove delist: AEA
# Remove delist: AEZ
# Remove delist: BDLN
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: BKI1
# Remove delist: BLC
# Remove delist: BZ
# Remove delist: CALP
# Remove delist: CGX
# Remove delist: CHRS1
# Remove delist: CLZR
# Remove delist: CPWM
# Remove delist: CPX
# Remove delist: DDRX
# Remove delist: DEIX
# Remove delist: DTG
# Remove delist: EDAC
# Remove delist: FIRE
# Remove delist: FSII
# Remove delist: HMA
# Remove delist: HTLLQ
# Remove delist: INHX
# Remove delist: INOC
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: KEI
# Remove delist: KNXA
# Remove delist: LCC
# Remove delist: LCRY
# Remove delist: MAPP
# Remove delist: MCBI1
# Remove delist: NAVI1
# Remove delist: NFP
# Remove delist: PBTH
# Remove delist: PPKZ
# Remove delist: PTYA
# Remove delist: PWER
# Remove delist: PXPLY
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SFN1
# Remove delist: SHF
# Remove delist: SHS
# Remove delist: SNIC
# Remove delist: SNTS
# Remove delist: SPRD
# Remove delist: SRZ
# Remove delist: SSCCQ
# Remove delist: TPCG
# Remove delist: TRXBQ
# Remove delist: VMED
# Remove delist: VPHM
# Remove delist: VRUS
# Remove delist: WCSTF
# Remove delist: YMI
# Remove delist: ZARLF
#         appreciation  10bagger
# ticker
# AAL        36.794788      True
# AAMC       61.470667      True
# AAME       10.205145      True
# AAPL       14.455728      True
# AAXN       11.948262      True
# ...              ...       ...
# YY         14.600265      True
# ZARLF      22.222222      True
# ZIOP       11.612418      True
# ZLC        18.892857      True
# ZPCM       85.680282      True
#
# [817 rows x 2 columns]
# Remove delist: AEA
# Remove delist: AEZ
# Remove delist: ARTC
# Remove delist: ATHYQ
# Remove delist: ATX
# Remove delist: AVNR
# Remove delist: BDLN
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: BKI1
# Remove delist: BLC
# Remove delist: BWEBF
# Remove delist: BZ
# Remove delist: CALP
# Remove delist: CBST
# Remove delist: CCIX
# Remove delist: CHRS1
# Remove delist: CLZR
# Remove delist: CPWM
# Remove delist: CPX
# Remove delist: CSE
# Remove delist: DDRX
# Remove delist: DEIX
# Remove delist: DTG
# Remove delist: EDAC
# Remove delist: EVOQ
# Remove delist: FIRE
# Remove delist: FSII
# Remove delist: GENTY
# Remove delist: GRT
# Remove delist: HTLLQ
# Remove delist: INHX
# Remove delist: INOC
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: KEI
# Remove delist: KFN
# Remove delist: KNXA
# Remove delist: KOG
# Remove delist: LCC
# Remove delist: LCRY
# Remove delist: MAPP
# Remove delist: MASC
# Remove delist: MEAS
# Remove delist: MGAM
# Remove delist: NAVI1
# Remove delist: NFP
# Remove delist: PBTH
# Remove delist: PPKZ
# Remove delist: PTYA
# Remove delist: PWER
# Remove delist: PXPLY
# Remove delist: QCOR
# Remove delist: RFMD
# Remove delist: ROC
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SFN1
# Remove delist: SHF
# Remove delist: SHS
# Remove delist: SNIC
# Remove delist: SNTS
# Remove delist: SPRD
# Remove delist: SRZ
# Remove delist: SSCCQ
# Remove delist: TPCG
# Remove delist: TQNT
# Remove delist: TRXBQ
# Remove delist: TVL
# Remove delist: VCI
# Remove delist: VMED
# Remove delist: VPHM
# Remove delist: VRUS
# Remove delist: VRYA
# Remove delist: WCSTF
# Remove delist: YMI
# Remove delist: ZARLF
# Remove delist: ZLC
#         appreciation  10bagger
# ticker
# AAL        24.820642      True
# AAME       11.081949      True
# AAPL       11.885981      True
# ABCB       10.355572      True
# ABCP       16.918258      True
# ...              ...       ...
# YY         10.250117      True
# ZAGG       11.660241      True
# ZARLF      22.222222      True
# ZIOP       16.792486      True
# ZLC        18.892857      True
#
# [576 rows x 2 columns]
# Remove delist: AEA
# Remove delist: AEZ
# Remove delist: ARTC
# Remove delist: ATLS1
# Remove delist: ATX
# Remove delist: AVNR
# Remove delist: BDLN
# Remove delist: BEE
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: BKI1
# Remove delist: BLC
# Remove delist: BWEBF
# Remove delist: BZ
# Remove delist: CALP
# Remove delist: CCIX
# Remove delist: CHRS1
# Remove delist: CLZR
# Remove delist: CMTX
# Remove delist: CPWM
# Remove delist: CPX
# Remove delist: CSE
# Remove delist: CTRX
# Remove delist: CYT
# Remove delist: DDRX
# Remove delist: DEIX
# Remove delist: DTG
# Remove delist: DYAX
# Remove delist: EDAC
# Remove delist: EVOQ
# Remove delist: FIRE
# Remove delist: FSII
# Remove delist: GENTY
# Remove delist: GEVA
# Remove delist: GRT
# Remove delist: HILL
# Remove delist: HTLLQ
# Remove delist: IGTE
# Remove delist: INHX
# Remove delist: INOC
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: ISSI
# Remove delist: JRN
# Remove delist: KEI
# Remove delist: KFN
# Remove delist: KNXA
# Remove delist: KOG
# Remove delist: LBMH
# Remove delist: LCC
# Remove delist: LCRY
# Remove delist: MAPP
# Remove delist: MASC
# Remove delist: MEAS
# Remove delist: MGAM
# Remove delist: NAVI1
# Remove delist: NFP
# Remove delist: PBTH
# Remove delist: PCYC
# Remove delist: PL
# Remove delist: PLNR
# Remove delist: PPKZ
# Remove delist: PPO
# Remove delist: PTYA
# Remove delist: PWER
# Remove delist: PXPLY
# Remove delist: QCOR
# Remove delist: RCPT
# Remove delist: RFMD
# Remove delist: RIOM
# Remove delist: ROC
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SFN1
# Remove delist: SHF
# Remove delist: SHS
# Remove delist: SLXP
# Remove delist: SNIC
# Remove delist: SNTS
# Remove delist: SPRD
# Remove delist: SRZ
# Remove delist: SSCCQ
# Remove delist: TPCG
# Remove delist: TQNT
# Remove delist: TRW
# Remove delist: TRXBQ
# Remove delist: TVL
# Remove delist: VCI
# Remove delist: VMED
# Remove delist: VPHM
# Remove delist: VRUS
# Remove delist: VRYA
# Remove delist: WCSTF
# Remove delist: WX
# Remove delist: YMI
# Remove delist: ZARLF
# Remove delist: ZLC
#         appreciation  10bagger
# ticker
# AAL        24.042074      True
# AAPL       11.578545      True
# ABCB       11.833011      True
# ABG        28.908446      True
# ABMD       23.843761      True
# ...              ...       ...
# XPO        16.051065      True
# YMI        12.250000      True
# YUANF      13.502897      True
# ZARLF      22.222222      True
# ZLC        18.892857      True
#
# [574 rows x 2 columns]
# Remove delist: ACAS
# Remove delist: AEA
# Remove delist: AEPI
# Remove delist: AEZ
# Remove delist: AFOP
# Remove delist: AICIQ
# Remove delist: ANAC
# Remove delist: ARMH
# Remove delist: ARTC
# Remove delist: ATLS1
# Remove delist: ATX
# Remove delist: AVNR
# Remove delist: BDLN
# Remove delist: BEE
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: BKI1
# Remove delist: BLC
# Remove delist: BWEBF
# Remove delist: BZ
# Remove delist: CALP
# Remove delist: CCIX
# Remove delist: CHRS1
# Remove delist: CKEC
# Remove delist: CLZR
# Remove delist: CMTX
# Remove delist: CPWM
# Remove delist: CPX
# Remove delist: CSE
# Remove delist: CTRX
# Remove delist: CYT
# Remove delist: DDRX
# Remove delist: DEIX
# Remove delist: DTG
# Remove delist: DYAX
# Remove delist: EDAC
# Remove delist: EVOQ
# Remove delist: FIRE
# Remove delist: FNAM
# Remove delist: FSII
# Remove delist: GENTY
# Remove delist: GEVA
# Remove delist: GMCR
# Remove delist: GMKYY
# Remove delist: GRT
# Remove delist: HILL
# Remove delist: HPY
# Remove delist: HTLLQ
# Remove delist: IGTE
# Remove delist: IMOS1
# Remove delist: INHX
# Remove delist: INOC
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: ISSI
# Remove delist: JAH
# Remove delist: JRN
# Remove delist: KEI
# Remove delist: KFN
# Remove delist: KKD
# Remove delist: KNXA
# Remove delist: KOG
# Remove delist: LCC
# Remove delist: LCRY
# Remove delist: MAPP
# Remove delist: MASC
# Remove delist: MDVN
# Remove delist: MEAS
# Remove delist: MEG
# Remove delist: MGAM
# Remove delist: N
# Remove delist: NAVI1
# Remove delist: NFP
# Remove delist: PBTH
# Remove delist: PCYC
# Remove delist: PL
# Remove delist: PLNR
# Remove delist: PPKZ
# Remove delist: PPO
# Remove delist: PTYA
# Remove delist: PWER
# Remove delist: PXPLY
# Remove delist: QCOR
# Remove delist: RCPT
# Remove delist: RFMD
# Remove delist: RIOM
# Remove delist: ROC
# Remove delist: ROGP
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SFN1
# Remove delist: SHF
# Remove delist: SHS
# Remove delist: SIRO
# Remove delist: SLI
# Remove delist: SLXP
# Remove delist: SNIC
# Remove delist: SNTS
# Remove delist: SPRD
# Remove delist: SRZ
# Remove delist: SSCCQ
# Remove delist: STRZA
# Remove delist: TPCG
# Remove delist: TQNT
# Remove delist: TRW
# Remove delist: TRXBQ
# Remove delist: TVL
# Remove delist: VCI
# Remove delist: VMED
# Remove delist: VPHM
# Remove delist: VRUS
# Remove delist: VRYA
# Remove delist: WCSTF
# Remove delist: WX
# Remove delist: YMI
# Remove delist: ZARLF
# Remove delist: ZLC
#         appreciation  10bagger
# ticker
# AAL        23.908947      True
# AAPL       15.238195      True
# ABCB       11.744281      True
# ABG        26.722942      True
# ABMD       35.461454      True
# ...              ...       ...
# YUANF      17.677696      True
# YY         12.202141      True
# ZAGG       15.696804      True
# ZARLF      22.222222      True
# ZLC        18.892857      True
#
# [618 rows x 2 columns]
# Remove delist: ACAS
# Remove delist: AEA
# Remove delist: AEZ
# Remove delist: AFOP
# Remove delist: AICIQ
# Remove delist: ANAC
# Remove delist: ARIA
# Remove delist: ARIS
# Remove delist: ARMH
# Remove delist: ARTC
# Remove delist: ATLS1
# Remove delist: ATX
# Remove delist: AVNR
# Remove delist: BDLN
# Remove delist: BEE
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: BKI1
# Remove delist: BLC
# Remove delist: BWEBF
# Remove delist: BZ
# Remove delist: CALP
# Remove delist: CCIX
# Remove delist: CHRS1
# Remove delist: CKEC
# Remove delist: CLZR
# Remove delist: CMTX
# Remove delist: CPWM
# Remove delist: CPX
# Remove delist: CSE
# Remove delist: CTRX
# Remove delist: CYNO
# Remove delist: CYT
# Remove delist: DDRX
# Remove delist: DEIX
# Remove delist: DFT
# Remove delist: DTG
# Remove delist: DTRX
# Remove delist: DYAX
# Remove delist: EDAC
# Remove delist: ERS
# Remove delist: EVOQ
# Remove delist: FIRE
# Remove delist: FNAM
# Remove delist: FSII
# Remove delist: GENTY
# Remove delist: GEVA
# Remove delist: GMCR
# Remove delist: GMKYY
# Remove delist: GRT
# Remove delist: HAR
# Remove delist: HILL
# Remove delist: HPY
# Remove delist: HSNI
# Remove delist: HTLLQ
# Remove delist: HW
# Remove delist: IGTE
# Remove delist: IMOS1
# Remove delist: INHX
# Remove delist: INOC
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: ISSI
# Remove delist: JAH
# Remove delist: JRN
# Remove delist: KEI
# Remove delist: KFN
# Remove delist: KKD
# Remove delist: KNXA
# Remove delist: KOG
# Remove delist: LCC
# Remove delist: LCRY
# Remove delist: MAPP
# Remove delist: MASC
# Remove delist: MDVN
# Remove delist: MEAS
# Remove delist: MEG
# Remove delist: MGAM
# Remove delist: N
# Remove delist: NAVI1
# Remove delist: NFP
# Remove delist: NTL
# Remove delist: PACI
# Remove delist: PBTH
# Remove delist: PCYC
# Remove delist: PL
# Remove delist: PLKI
# Remove delist: PLNR
# Remove delist: PPKZ
# Remove delist: PPO
# Remove delist: PRXL
# Remove delist: PTYA
# Remove delist: PWER
# Remove delist: PXPLY
# Remove delist: QCOR
# Remove delist: QUSA
# Remove delist: RCPT
# Remove delist: RFMD
# Remove delist: RIOM
# Remove delist: ROC
# Remove delist: ROGP
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SCLN
# Remove delist: SEV
# Remove delist: SFN1
# Remove delist: SHF
# Remove delist: SHS
# Remove delist: SIRO
# Remove delist: SLI
# Remove delist: SLXP
# Remove delist: SNIC
# Remove delist: SNTS
# Remove delist: SPNC
# Remove delist: SPRD
# Remove delist: SRZ
# Remove delist: SSCCQ
# Remove delist: STRZA
# Remove delist: STS
# Remove delist: TPCG
# Remove delist: TQNT
# Remove delist: TRW
# Remove delist: TRXBQ
# Remove delist: TVL
# Remove delist: VASC
# Remove delist: VCI
# Remove delist: VMED
# Remove delist: VPHM
# Remove delist: VRUS
# Remove delist: VRYA
# Remove delist: WCSTF
# Remove delist: WX
# Remove delist: YMI
# Remove delist: ZARLF
# Remove delist: ZLC
#         appreciation  10bagger
# ticker
# AAL        13.300752      True
# AAPL       12.845540      True
# AAXN       12.397788      True
# ABG        25.096510      True
# ABMD       55.413601      True
# ...              ...       ...
# XPO        17.171871      True
# YMI        12.250000      True
# YUANF      11.323845      True
# ZARLF      22.222222      True
# ZLC        18.892857      True
#
# [475 rows x 2 columns]
# Remove delist: ACAS
# Remove delist: AEA
# Remove delist: AET
# Remove delist: AEZ
# Remove delist: AFOP
# Remove delist: AICIQ
# Remove delist: ANAC
# Remove delist: ANDV
# Remove delist: ARIA
# Remove delist: ARII
# Remove delist: ARIS
# Remove delist: ARMH
# Remove delist: ARTC
# Remove delist: ATLS1
# Remove delist: ATX
# Remove delist: AVNR
# Remove delist: AVXS
# Remove delist: BDLN
# Remove delist: BEE
# Remove delist: BELM
# Remove delist: BEXP
# Remove delist: BKI1
# Remove delist: BLC
# Remove delist: BWEBF
# Remove delist: BZ
# Remove delist: CAA
# Remove delist: CALD
# Remove delist: CALP
# Remove delist: CCIX
# Remove delist: CHRS1
# Remove delist: CKEC
# Remove delist: CLZR
# Remove delist: CMTX
# Remove delist: CPWM
# Remove delist: CPX
# Remove delist: CSE
# Remove delist: CTRX
# Remove delist: CYNO
# Remove delist: CYT
# Remove delist: DDRX
# Remove delist: DEIX
# Remove delist: DFT
# Remove delist: DTG
# Remove delist: DTRX
# Remove delist: DWCH
# Remove delist: DYAX
# Remove delist: EDAC
# Remove delist: ELXS
# Remove delist: ERS
# Remove delist: EVOQ
# Remove delist: FFNM
# Remove delist: FIRE
# Remove delist: FNAM
# Remove delist: FSII
# Remove delist: GENTY
# Remove delist: GEVA
# Remove delist: GGP
# Remove delist: GMCR
# Remove delist: GMKYY
# Remove delist: GPT
# Remove delist: GRT
# Remove delist: HAR
# Remove delist: HILL
# Remove delist: HPY
# Remove delist: HSNI
# Remove delist: HTLLQ
# Remove delist: HW
# Remove delist: IGTE
# Remove delist: IMOS1
# Remove delist: INHX
# Remove delist: INOC
# Remove delist: IRMC
# Remove delist: ISLN
# Remove delist: ISSI
# Remove delist: JAH
# Remove delist: JRN
# Remove delist: KEI
# Remove delist: KERX
# Remove delist: KFN
# Remove delist: KKD
# Remove delist: KMG
# Remove delist: KNXA
# Remove delist: KOG
# Remove delist: KS
# Remove delist: LCC
# Remove delist: LCRY
# Remove delist: MAPP
# Remove delist: MASC
# Remove delist: MDVN
# Remove delist: MEAS
# Remove delist: MEG
# Remove delist: MGAM
# Remove delist: N
# Remove delist: NAVI1
# Remove delist: NFP
# Remove delist: NTL
# Remove delist: PACI
# Remove delist: PBTH
# Remove delist: PCYC
# Remove delist: PL
# Remove delist: PLKI
# Remove delist: PLNR
# Remove delist: PPKZ
# Remove delist: PPO
# Remove delist: PRXL
# Remove delist: PTYA
# Remove delist: PWER
# Remove delist: PXPLY
# Remove delist: QCOR
# Remove delist: QUSA
# Remove delist: RCPT
# Remove delist: RFMD
# Remove delist: RIOM
# Remove delist: ROC
# Remove delist: ROGP
# Remove delist: RURL
# Remove delist: RVI1
# Remove delist: SCLN
# Remove delist: SEV
# Remove delist: SFN1
# Remove delist: SHF
# Remove delist: SHS
# Remove delist: SIRO
# Remove delist: SLI
# Remove delist: SLXP
# Remove delist: SNIC
# Remove delist: SNTS
# Remove delist: SPNC
# Remove delist: SPRD
# Remove delist: SRZ
# Remove delist: SSCCQ
# Remove delist: STRP
# Remove delist: STRZA
# Remove delist: STS
# Remove delist: TPCG
# Remove delist: TQNT
# Remove delist: TRW
# Remove delist: TRXBQ
# Remove delist: TVL
# Remove delist: VASC
# Remove delist: VCI
# Remove delist: VMED
# Remove delist: VPHM
# Remove delist: VRUS
# Remove delist: VRYA
# Remove delist: WCSTF
# Remove delist: WX
# Remove delist: XCRA
# Remove delist: XL
# Remove delist: YMI
# Remove delist: ZARLF
# Remove delist: ZLC

# %%
prospects['2018-12-31']
# Out:
#         appreciation  10bagger
# ticker
# AAL        13.300752      True
# AAPL       12.845540      True
# AAXN       12.397788      True
# ABG        25.096510      True
# ABMD       55.413601      True
# ...              ...       ...
# WLK        11.500578      True
# WNS        11.723294      True
# WYND       11.455639      True
# XPO        17.171871      True
# YUANF      11.323845      True
#
# [323 rows x 2 columns]

# %% [markdown]
# ## Useful Functions

# %%
def random_select(prospects, num_tickers, invalids=[]):
    # Randomly pick a number of valid tickers from prospect_list
   
    if (len(prospects)-len(invalids)) < num_tickers:
        print('Not enough tickers in prospect list!')
        selections = None
    else:
        selections = []
        num = 0
        while num < num_tickers:
            ticker = random.sample(prospects, 1)  # pick a ticker
            if not (ticker[0] in invalids+selections):
                # print(ticker[0])
                # print(invalids+selections)
                selections.append(ticker[0])  # add to select if ticker is valid and has not been picked already
                num += 1
    return selections

def average_price(ticker, start, end):
    # Calculate average price of a ticker in period between start and end
    # The function assumes there is a global dataset "prices"
    
    # get the ticker's prices in the period (drop the NaNs)
    prices_history = list(prices[ticker].loc[start:end].dropna())   
    
    return sum(prices_history)/len(prices_history)

def liquidate(tickers, holdings, start, end, debug=False):
    # Liquidate holding in period between start and end
    # The function assumes there is a global dataset "prices"

    total = 0
    price_list = []
    
    for ticker in tickers:
        if math.isnan(prices[ticker].loc[start]):
            # If stock has been delisted before rebalance period, get price at date of delist
            delist_price = prices[ticker].loc[prices[ticker].last_valid_index()] 
            price_list.append(delist_price)
        else:
            price_list.append(average_price(ticker, start, end)) 
   
    for ticker, num_shares, price in zip(tickers, holdings, price_list):
        if debug:
            print("{}: Liquidate {:.1f} sh at ${:.2f}".format(ticker, num_shares, price))
        total += num_shares * price
        
    return total

def invest_evenly(tickers, holdings, cash, start, end, debug=False):
    # Invest the cash evenly between the tickers over the rebalancing period (defined by start and end). 
    # Return updated holding as a list. 
    
    new_holdings = []
    
    for ticker, holding in zip(tickers, holdings):

        buy_price = average_price(ticker, start, end) # find average price during rebalance period
        shares_added = cash/buy_price   # calculate and save number of shares bought
        new_holdings.append(holding + shares_added)

        if debug:
            print("{}: Buy {:.1f} sh at ${:.2f}".format(ticker, shares_added, buy_price))
    
    return new_holdings
    

def portfolio_value(tickers, holdings, date, debug=False):
    # Value of portfolio on a specific date
    # The function assumes there is a global dataset "prices"
    
    # print('Calculate value of stock holdings on {}:'.format(date))

    total = 0
    price_list = []
    
    for ticker in tickers:
        if math.isnan(prices[ticker].loc[date]):
            # If stock has been delisted before rebalance period, get price at date of delist
            delist_price = prices[ticker].loc[prices[ticker].last_valid_index()] 
            price_list.append(delist_price)
        else:
            price_list.append(prices[ticker].loc[date]) 
   
    for ticker, num_shares, price in zip(tickers, holdings, price_list):
        if debug:
            print("{}: {:.1f} sh at ${:.2f}".format(ticker, num_shares, price))
        total += num_shares * price
        
    return total

def identify_winners(tickers, prospects):
    # If a ticker in the portfolio is in the prospect list, identify it as a winner.
    
    winners = []
    losers = []
    
    for ticker in tickers:
        if ticker in prospects:
            winners.append(ticker)
        else:
            losers.append(ticker)
    
    return winners, losers

def prune_losers(portfolio, tickers, debug=False):
    # Take the input portfolio and prune away the losers
    loser_tickers = []
    loser_holdings = []
    new_portfolio = {}
    new_portfolio['tickers']=[]
    new_portfolio['num_shares']=[]
    
    for ticker, num_shares in zip(portfolio['tickers'], portfolio['num_shares']):
        if ticker in tickers:
            if debug:
                print('Loser: {}sh of {}'.format(num_shares, ticker))
            # Sell the losers
            loser_tickers.append(ticker)
            loser_holdings.append(num_shares) 
        else:
            # keep the winners
            if debug:
                print('Winner: {}sh of {}'.format(num_shares, ticker))
            new_portfolio['tickers'].append(ticker)
            new_portfolio['num_shares'].append(num_shares) 
            
    return new_portfolio, loser_tickers, loser_holdings

# %% [markdown]
# # Implement Strategy One (Shotgun then Prune)

# %%
num_iterations = 2000
returns = []
debug = False

for i in range(num_iterations):
    
    # Execute Strategy One 

    portfolio = {}
    last = None   # to save the last portfolio
    start_cash = START  # Start with $10M

    for date, num_tickers, rebalance_period in zip(end_dates,portfolio_sizes, rebalance_periods):
        
        if debug:
            print('Portfolio: {}'.format(date))
        start, end = rebalance_period

        if last is None:  # Create the portfolio for the first time

            if debug:
                print("Shotgun!")

            portfolio[date] = {}
            # Randomly select a set number of tickers from the prospect list (SHOTGUN)
            portfolio[date]['tickers'] = random_select(list(prospects[date].index), num_tickers)  
            portfolio[date]['num_shares'] = [0 for x in portfolio[date]['tickers']]

            # Invest cash evenly between the tickers
            invest = start_cash/num_tickers  
            portfolio[date]['num_shares'] = invest_evenly(portfolio[date]['tickers'], \
                                                         portfolio[date]['num_shares'], \
                                                         invest, start, end, debug=debug)

            last = portfolio[date].copy()   # Save a copy of the portfolio for later iterations
            cash = 0  # No more cash left

        else:   # Prune portfolio - Keep only the Winners

            if debug:
                print("Prune!")

            portfolio[date] = {}
            loser_tickers = []
            loser_holdings = []

            # If a ticker in the portfolio is on the new prospect list, keep it as a Winner.
            # If a ticker is not on the new prospect list, sell its position for cash
            winners, losers = identify_winners(last['tickers'], list(prospects[date].index))
            portfolio[date],loser_tickers,loser_holdings = prune_losers(last, losers, debug=debug)  

            # Liquidate Losers for cash during rebalance period
            liquidation = liquidate(loser_tickers, loser_holdings, start, end, debug=debug)
            cash += liquidation

            if debug:
                print('Winners: {}'.format(winners))
                print('Losers: {}'.format(losers))
                print('Cash harvested from Losers: ${:.2f}'.format(liquidation))   
                print('\n')

            last = portfolio[date].copy()   # Save portfolio for later iterations

    # Calculate value of the stock holdings on target date
    equity = portfolio_value(last['tickers'], last['num_shares'], target_date)
    total = equity + cash
    
    # Calculate and save portfolio return
    portfolio_return = (total/start_cash-1)*100
    returns.append(portfolio_return)

    print('Equity is valued at: ${:.2f}'.format(equity))
    print('Cash Position: ${:.2f}'.format(cash))
    print('Portfolio Total: ${:.2f}'.format(total))
    print('Portfolio appreciates by {:.1f} %'.format(portfolio_return))
    print('\n')
# Out:
# Equity is valued at: $8746819.25
# Cash Position: $7762151.37
# Portfolio Total: $16508970.62
# Portfolio appreciates by 65.1 %
#
#
# Equity is valued at: $8264552.32
# Cash Position: $7839797.98
# Portfolio Total: $16104350.31
# Portfolio appreciates by 61.0 %
#
#
# Equity is valued at: $3830202.33
# Cash Position: $7835699.67
# Portfolio Total: $11665902.00
# Portfolio appreciates by 16.7 %
#
#
# Equity is valued at: $2293762.64
# Cash Position: $9064476.71
# Portfolio Total: $11358239.35
# Portfolio appreciates by 13.6 %
#
#
# Equity is valued at: $3044853.84
# Cash Position: $9693877.92
# Portfolio Total: $12738731.76
# Portfolio appreciates by 27.4 %
#
#
# Equity is valued at: $4598934.14
# Cash Position: $7965947.29
# Portfolio Total: $12564881.43
# Portfolio appreciates by 25.6 %
#
#
# Equity is valued at: $3485899.09
# Cash Position: $8139545.14
# Portfolio Total: $11625444.22
# Portfolio appreciates by 16.3 %
#
#
# Equity is valued at: $8344380.79
# Cash Position: $8350092.84
# Portfolio Total: $16694473.64
# Portfolio appreciates by 66.9 %
#
#
# Equity is valued at: $2597171.75
# Cash Position: $11940411.93
# Portfolio Total: $14537583.68
# Portfolio appreciates by 45.4 %
#
#
# Equity is valued at: $1713196.46
# Cash Position: $8940148.47
# Portfolio Total: $10653344.92
# Portfolio appreciates by 6.5 %
#
#
# Equity is valued at: $2720128.44
# Cash Position: $8737504.70
# Portfolio Total: $11457633.13
# Portfolio appreciates by 14.6 %
#
#
# Equity is valued at: $9535767.70
# Cash Position: $7784017.79
# Portfolio Total: $17319785.49
# Portfolio appreciates by 73.2 %
#
#
# Equity is valued at: $12715751.11
# Cash Position: $9024120.63
# Portfolio Total: $21739871.74
# Portfolio appreciates by 117.4 %
#
#
# Equity is valued at: $4458916.54
# Cash Position: $8377140.53
# Portfolio Total: $12836057.07
# Portfolio appreciates by 28.4 %
#
#
# Equity is valued at: $3534015.93
# Cash Position: $8153459.27
# Portfolio Total: $11687475.20
# Portfolio appreciates by 16.9 %
#
#
# Equity is valued at: $2888780.08
# Cash Position: $7890165.90
# Portfolio Total: $10778945.98
# Portfolio appreciates by 7.8 %
#
#
# Equity is valued at: $2951054.32
# Cash Position: $9270174.22
# Portfolio Total: $12221228.54
# Portfolio appreciates by 22.2 %
#
#
# Equity is valued at: $9325342.91
# Cash Position: $7695195.34
#
#
# Equity is valued at: $8266463.80
# Cash Position: $8899562.79
# Portfolio Total: $17166026.58
# Portfolio appreciates by 71.7 %
#
#
# Equity is valued at: $2877918.07
# Cash Position: $7721537.09
# Portfolio Total: $10599455.16
# Portfolio appreciates by 6.0 %
#
#
# Equity is valued at: $852412.50
# Cash Position: $9595748.84
# Portfolio Total: $10448161.33
# Portfolio appreciates by 4.5 %
#
#
# Equity is valued at: $2934995.12
# Cash Position: $7072423.98
# Portfolio Total: $10007419.09
# Portfolio appreciates by 0.1 %
#
#
# Equity is valued at: $2220735.95
# Cash Position: $9136155.42
# Portfolio Total: $11356891.37
# Portfolio appreciates by 13.6 %
#
#
# Equity is valued at: $2194763.32
# Cash Position: $8596712.25
# Portfolio Total: $10791475.57
# Portfolio appreciates by 7.9 %
#
#
# Equity is valued at: $3230910.55
# Cash Position: $11606717.68
# Portfolio Total: $14837628.23
# Portfolio appreciates by 48.4 %
#
#
# Equity is valued at: $2297240.73
# Cash Position: $7338666.71
# Portfolio Total: $9635907.44
# Portfolio appreciates by -3.6 %
#
#
# Equity is valued at: $5219470.95
# Cash Position: $8860385.94
# Portfolio Total: $14079856.89
# Portfolio appreciates by 40.8 %
#
#
# Equity is valued at: $3035719.62
# Cash Position: $8127230.44
# Portfolio Total: $11162950.06
# Portfolio appreciates by 11.6 %
#
#
# Equity is valued at: $5347803.58
# Cash Position: $6572320.32
# Portfolio Total: $11920123.90
# Portfolio appreciates by 19.2 %
#
#
# Equity is valued at: $3443113.42
# Cash Position: $9111877.97
# Portfolio Total: $12554991.39
# Portfolio appreciates by 25.5 %
#
#
# Equity is valued at: $1812017.64
# Cash Position: $9102878.83
# Portfolio Total: $10914896.47
# Portfolio appreciates by 9.1 %
#
#
# Equity is valued at: $4581440.52
# Cash Position: $8801290.45
# Portfolio Total: $13382730.97
# Portfolio appreciates by 33.8 %
#
#
# Equity is valued at: $2275331.07
# Cash Position: $8394461.29
# Portfolio Total: $10669792.36
# Portfolio appreciates by 6.7 %
#
#
# Equity is valued at: $4698446.33
# Cash Position: $7909641.16
# Portfolio Total: $12608087.49
# Portfolio appreciates by 26.1 %
#
#
# Equity is valued at: $3275862.68
# Cash Position: $7928259.25
# Portfolio Total: $11204121.93
# Portfolio appreciates by 12.0 %
#
#
# Equity is valued at: $1689513.00
# Cash Position: $8055494.03
# Portfolio Total: $9745007.03
# Portfolio appreciates by -2.5 %
#
#
# Equity is valued at: $4479330.83
# Cash Position: $8021297.23
# Portfolio Total: $12500628.07
# Portfolio appreciates by 25.0 %
#
#
# Equity is valued at: $2667690.50
# Cash Position: $7708971.38
# Portfolio Total: $10376661.88
# Portfolio appreciates by 3.8 %
#
#
# Equity is valued at: $4065833.08
# Cash Position: $8181303.07
# Portfolio Total: $12247136.15
# Portfolio appreciates by 22.5 %
#
#
# Equity is valued at: $4162094.65
# Cash Position: $7849353.29
# Portfolio Total: $12011447.94
# Portfolio appreciates by 20.1 %
#
#
# Equity is valued at: $3855826.32
# Cash Position: $11418565.01
# Portfolio Total: $15274391.33
#
#
# Equity is valued at: $4770786.46
# Cash Position: $8576813.53
# Portfolio Total: $13347599.99
# Portfolio appreciates by 33.5 %
#
#
# Equity is valued at: $3607214.82
# Cash Position: $7647999.95
# Portfolio Total: $11255214.77
# Portfolio appreciates by 12.6 %
#
#
# Equity is valued at: $3554442.49
# Cash Position: $8901768.44
# Portfolio Total: $12456210.93
# Portfolio appreciates by 24.6 %
#
#
# Equity is valued at: $1373009.61
# Cash Position: $8988900.21
# Portfolio Total: $10361909.82
# Portfolio appreciates by 3.6 %
#
#
# Equity is valued at: $1381605.82
# Cash Position: $7744840.03
# Portfolio Total: $9126445.85
# Portfolio appreciates by -8.7 %
#
#
# Equity is valued at: $2379365.71
# Cash Position: $12610421.16
# Portfolio Total: $14989786.87
# Portfolio appreciates by 49.9 %
#
#
# Equity is valued at: $3464316.56
# Cash Position: $8126628.17
# Portfolio Total: $11590944.73
# Portfolio appreciates by 15.9 %
#
#
# Equity is valued at: $4792143.56
# Cash Position: $7599055.34
# Portfolio Total: $12391198.90
# Portfolio appreciates by 23.9 %
#
#
# Equity is valued at: $4677962.44
# Cash Position: $7642495.14
# Portfolio Total: $12320457.58
# Portfolio appreciates by 23.2 %
#
#
# Equity is valued at: $3284046.32
# Cash Position: $7584487.44
# Portfolio Total: $10868533.76
# Portfolio appreciates by 8.7 %
#
#
# Equity is valued at: $2775204.17
# Cash Position: $8039819.63
# Portfolio Total: $10815023.80
# Portfolio appreciates by 8.2 %
#
#
# Equity is valued at: $2689860.55
# Cash Position: $11712379.90
# Portfolio Total: $14402240.45
# Portfolio appreciates by 44.0 %
#
#
# Equity is valued at: $1428942.35
# Cash Position: $8426277.24
# Portfolio Total: $9855219.59
# Portfolio appreciates by -1.4 %
#
#
# Equity is valued at: $1985024.29
# Cash Position: $7848825.72
# Portfolio Total: $9833850.01
# Portfolio appreciates by -1.7 %
#
#
# Equity is valued at: $13178793.47
# Cash Position: $8110842.26
# Portfolio Total: $21289635.73
# Portfolio appreciates by 112.9 %
#
#
# Equity is valued at: $8625847.66
# Cash Position: $8067722.86
# Portfolio Total: $16693570.51
# Portfolio appreciates by 66.9 %
#
#
# Equity is valued at: $1565299.93
# Cash Position: $8444121.71
# Portfolio Total: $10009421.64
# Portfolio appreciates by 0.1 %
#
#
# Equity is valued at: $1609032.53
# Cash Position: $9494922.13
# Portfolio Total: $11103954.66
# Portfolio appreciates by 11.0 %
#
#
# Equity is valued at: $1262933.54
# Cash Position: $8709888.26
# Portfolio Total: $9972821.80
# Portfolio appreciates by -0.3 %
#
#
# Equity is valued at: $3408350.94
# Cash Position: $8451801.71
# Portfolio Total: $11860152.65
# Portfolio appreciates by 18.6 %
#
#
# Equity is valued at: $2436206.29
# Cash Position: $8082562.72
# Portfolio Total: $10518769.02
# Portfolio appreciates by 5.2 %
#
#
# Equity is valued at: $1369203.60
# Cash Position: $8119187.21
# Portfolio Total: $9488390.81
# Portfolio appreciates by -5.1 %
#
#
# Equity is valued at: $2354525.20
# Cash Position: $8572348.08
# Cash Position: $7452372.05
# Portfolio Total: $9534335.12
# Portfolio appreciates by -4.7 %
#
#
# Equity is valued at: $2818594.27
# Cash Position: $8943496.79
# Portfolio Total: $11762091.05
# Portfolio appreciates by 17.6 %
#
#
# Equity is valued at: $1687051.30
# Cash Position: $8848696.37
# Portfolio Total: $10535747.67
# Portfolio appreciates by 5.4 %
#
#
# Equity is valued at: $2321111.11
# Cash Position: $8070422.95
# Portfolio Total: $10391534.06
# Portfolio appreciates by 3.9 %
#
#
# Equity is valued at: $2589339.41
# Cash Position: $8077698.75
# Portfolio Total: $10667038.16
# Portfolio appreciates by 6.7 %
#
#
# Equity is valued at: $2158933.59
# Cash Position: $8816061.00
# Portfolio Total: $10974994.59
# Portfolio appreciates by 9.7 %
#
#
# Equity is valued at: $831560.27
# Cash Position: $8170672.46
# Portfolio Total: $9002232.73
# Portfolio appreciates by -10.0 %
#
#
# Equity is valued at: $834523.27
# Cash Position: $8615351.58
# Portfolio Total: $9449874.85
# Portfolio appreciates by -5.5 %
#
#
# Equity is valued at: $210538.36
# Cash Position: $9519767.25
# Portfolio Total: $9730305.61
# Portfolio appreciates by -2.7 %
#
#
# Equity is valued at: $2088489.19
# Cash Position: $12410722.45
# Portfolio Total: $14499211.64
# Portfolio appreciates by 45.0 %
#
#
# Equity is valued at: $1741088.29
# Cash Position: $8400605.03
# Portfolio Total: $10141693.32
# Portfolio appreciates by 1.4 %
#
#
# Equity is valued at: $3175020.79
# Cash Position: $7764616.19
# Portfolio Total: $10939636.98
# Portfolio appreciates by 9.4 %
#
#
# Equity is valued at: $3000808.79
# Cash Position: $7856818.61
# Portfolio Total: $10857627.40
# Portfolio appreciates by 8.6 %
#
#
# Equity is valued at: $3881848.80
# Cash Position: $12422675.45
# Portfolio Total: $16304524.25
# Portfolio appreciates by 63.0 %
#
#
# Equity is valued at: $1530819.77
# Cash Position: $9175407.27
# Portfolio Total: $10706227.04
# Portfolio appreciates by 7.1 %
#
#
# Equity is valued at: $1409582.16
# Cash Position: $8807147.60
# Portfolio Total: $10216729.77
# Portfolio appreciates by 2.2 %
#
#
# Equity is valued at: $3447334.07
# Cash Position: $7866891.52
# Portfolio Total: $11314225.58
# Portfolio appreciates by 13.1 %
#
#
# Equity is valued at: $5023553.06
# Cash Position: $13053347.16
# Portfolio Total: $18076900.22
# Portfolio appreciates by 80.8 %
#
#
# Equity is valued at: $1406767.33
# Cash Position: $8842949.93
# Portfolio Total: $10249717.26
# Portfolio appreciates by 2.5 %
#
#
# Equity is valued at: $3679689.57
# Cash Position: $12331180.36
# Portfolio Total: $16010869.93
# Portfolio appreciates by 60.1 %
#
#
# Equity is valued at: $3177319.49
# Cash Position: $7191287.98
# Portfolio Total: $10368607.47
# Portfolio appreciates by 3.7 %
#
#
# Equity is valued at: $5289959.52
# Cash Position: $7879036.65
# Portfolio Total: $13168996.18
# Portfolio appreciates by 31.7 %
#
#
# Equity is valued at: $4789843.91
# Cash Position: $7432711.27
# Portfolio Total: $12222555.18
# Portfolio appreciates by 22.2 %
#
#
# Equity is valued at: $3857749.82
# Cash Position: $8609910.71
# Portfolio Total: $12467660.53
# Portfolio appreciates by 24.7 %
#
#
# Equity is valued at: $2792082.09
# Cash Position: $8442635.91
# Portfolio Total: $11234718.00
# Portfolio appreciates by 12.3 %
#
#
# Equity is valued at: $10539768.34
# Cash Position: $7710591.39
# Portfolio Total: $18250359.73
# Portfolio appreciates by 82.5 %
#
#
# Equity is valued at: $2791105.69
# Cash Position: $8504121.47
# Portfolio Total: $11295227.16
# Portfolio appreciates by 13.0 %
#
#
# Equity is valued at: $3912455.71
# Cash Position: $7884588.73
# Portfolio Total: $11797044.44
# Portfolio appreciates by 18.0 %
#
#
# Equity is valued at: $4041623.74
# Cash Position: $8689711.93
# Portfolio Total: $12731335.68
# Portfolio appreciates by 27.3 %
#
#
# Equity is valued at: $805966.79
# Cash Position: $11189130.43
# Portfolio Total: $11995097.22
# Portfolio appreciates by 20.0 %
#
#
# Equity is valued at: $3203820.39
# Cash Position: $7506831.02
# Portfolio Total: $10710651.41
# Portfolio appreciates by 7.1 %
#
#
# Equity is valued at: $2619766.89
# Cash Position: $7657125.56
# Portfolio Total: $10276892.45
# Portfolio appreciates by 2.8 %
#
#
# Equity is valued at: $1298223.12
# Cash Position: $7899571.61
# Portfolio Total: $9197794.73
# Portfolio appreciates by -8.0 %
#
#
# Equity is valued at: $3202197.53
# Cash Position: $8762052.03
# Portfolio Total: $11964249.56
# Portfolio appreciates by 19.6 %
#
#
# Equity is valued at: $4057145.36
# Cash Position: $7738696.14
# Portfolio Total: $11795841.50
# Portfolio appreciates by 18.0 %
#
#
# Equity is valued at: $3258885.83
# Cash Position: $7671229.91
# Portfolio Total: $10930115.74
# Portfolio appreciates by 9.3 %
#
#
# Equity is valued at: $5059833.99
# Cash Position: $8375400.96
# Portfolio Total: $13435234.95
# Portfolio appreciates by 34.4 %
#
#
# Equity is valued at: $2522785.18
# Cash Position: $8178316.65
# Portfolio Total: $10701101.83
# Portfolio appreciates by 7.0 %
#
#
# Equity is valued at: $1166195.28
# Cash Position: $13218304.31
# Portfolio Total: $14384499.59
# Portfolio appreciates by 43.8 %
#
#
# Equity is valued at: $9581592.13
# Cash Position: $7856040.16
# Portfolio Total: $17437632.29
# Portfolio appreciates by 74.4 %
#
#
# Equity is valued at: $10364535.88
# Cash Position: $9254106.08
# Portfolio Total: $19618641.96
# Portfolio appreciates by 96.2 %
#
#
# Equity is valued at: $3001272.93
# Cash Position: $9203198.67
# Portfolio Total: $12204471.60
# Portfolio appreciates by 22.0 %
#
#
# Equity is valued at: $3001342.49
# Cash Position: $13416194.48
# Portfolio Total: $16417536.97
# Portfolio appreciates by 64.2 %
#
#
# Equity is valued at: $1471152.28
# Cash Position: $10175452.43
# Portfolio Total: $11646604.71
# Portfolio appreciates by 16.5 %
#
#
# Equity is valued at: $1728450.83
# Cash Position: $8697032.39
# Portfolio Total: $10425483.22
# Portfolio appreciates by 4.3 %
#
#
# Equity is valued at: $1367144.84
# Cash Position: $8586023.11
# Portfolio Total: $9953167.96
# Portfolio appreciates by 99.2 %
#
#
# Equity is valued at: $3293140.90
# Cash Position: $9972473.32
# Portfolio Total: $13265614.22
# Portfolio appreciates by 32.7 %
#
#
# Equity is valued at: $3785278.26
# Cash Position: $9516518.61
# Portfolio Total: $13301796.87
# Portfolio appreciates by 33.0 %
#
#
# Equity is valued at: $3657930.76
# Cash Position: $8206877.67
# Portfolio Total: $11864808.43
# Portfolio appreciates by 18.6 %
#
#
# Equity is valued at: $2776294.77
# Cash Position: $10921217.43
# Portfolio Total: $13697512.21
# Portfolio appreciates by 37.0 %
#
#
# Equity is valued at: $3148608.03
# Cash Position: $7782277.39
# Portfolio Total: $10930885.42
# Portfolio appreciates by 9.3 %
#
#
# Equity is valued at: $4002448.83
# Cash Position: $8172592.72
# Portfolio Total: $12175041.56
# Portfolio appreciates by 21.8 %
#
#
# Equity is valued at: $3996178.55
# Cash Position: $7648974.35
# Portfolio Total: $11645152.90
# Portfolio appreciates by 16.5 %
#
#
# Equity is valued at: $11117689.44
# Cash Position: $7645408.10
# Portfolio Total: $18763097.54
# Portfolio appreciates by 87.6 %
#
#
# Equity is valued at: $2752444.45
# Cash Position: $8159968.89
# Portfolio Total: $10912413.34
# Portfolio appreciates by 9.1 %
#
#
# Equity is valued at: $5076155.14
# Cash Position: $8456652.27
# Portfolio Total: $13532807.41
# Portfolio appreciates by 35.3 %
#
#
# Equity is valued at: $4092946.06
# Cash Position: $7932229.02
# Portfolio Total: $12025175.08
# Portfolio appreciates by 20.3 %
# Equity is valued at: $1763028.83
# Cash Position: $8687654.21
# Portfolio Total: $10450683.04
# Portfolio appreciates by 4.5 %
#
#
# Equity is valued at: $1582636.15
# Cash Position: $7334498.37
# Portfolio Total: $8917134.52
# Portfolio appreciates by -10.8 %
#
#
# Equity is valued at: $1364710.80
# Cash Position: $8071591.54
# Portfolio Total: $9436302.34
# Portfolio appreciates by -5.6 %
#
#
# Equity is valued at: $1127237.95
# Cash Position: $8833626.69
# Portfolio Total: $9960864.64
# Portfolio appreciates by -0.4 %
#
#
# Equity is valued at: $2611178.46
# Cash Position: $10908961.23
# Portfolio Total: $13520139.68
# Portfolio appreciates by 35.2 %
#
#
# Equity is valued at: $3967363.23
# Cash Position: $7989239.07
# Portfolio Total: $11956602.31
# Portfolio appreciates by 19.6 %
#
#
# Equity is valued at: $3156183.90
# Cash Position: $13394486.79
# Portfolio Total: $16550670.69
# Portfolio appreciates by 65.5 %
#
#
# Equity is valued at: $1389729.33
# Cash Position: $9469696.87
# Portfolio Total: $10859426.20
# Portfolio appreciates by 8.6 %
#
#
# Equity is valued at: $1331619.26
# Cash Position: $10320879.04
# Portfolio Total: $11652498.30
# Portfolio appreciates by 16.5 %
#
#
# Equity is valued at: $1793766.64
# Cash Position: $9207493.48
# Portfolio Total: $11001260.12
# Portfolio appreciates by 10.0 %
#
#
# Equity is valued at: $2670164.40
# Cash Position: $8260677.58
# Portfolio Total: $10930841.98
# Portfolio appreciates by 9.3 %
#
#
# Equity is valued at: $3408816.23
# Portfolio Total: $15361142.04
# Portfolio appreciates by 53.6 %
#
#
# Equity is valued at: $3591521.76
# Cash Position: $8345375.01
# Portfolio Total: $11936896.77
# Portfolio appreciates by 19.4 %
#
#
# Equity is valued at: $5299001.90
# Cash Position: $7788231.90
# Portfolio Total: $13087233.80
# Portfolio appreciates by 30.9 %
#
#
# Equity is valued at: $3624926.66
# Cash Position: $12163448.81
# Portfolio Total: $15788375.47
# Portfolio appreciates by 57.9 %
#
#
# Equity is valued at: $1746040.28
# Cash Position: $7956924.42
# Portfolio Total: $9702964.70
# Portfolio appreciates by -3.0 %
#
#
# Equity is valued at: $2044013.23
# Cash Position: $7881806.76
# Portfolio Total: $9925819.98
# Portfolio appreciates by -0.7 %
#
#
# Equity is valued at: $1035931.19
# Cash Position: $8463107.17
# Portfolio Total: $9499038.36
# ...
#
#
# Equity is valued at: $1937033.59
# Cash Position: $8723795.32
# Portfolio Total: $10660828.91
# Portfolio appreciates by 6.6 %
#
#
# Equity is valued at: $1274271.72
# Cash Position: $8625372.19
# Portfolio Total: $9899643.91
# Portfolio appreciates by -1.0 %
#
#
# Equity is valued at: $5990899.01
# Cash Position: $6900318.98
# Portfolio Total: $12891217.99
# Portfolio appreciates by 28.9 %
#
#
# Equity is valued at: $1975216.54
# Cash Position: $9292486.04
# Portfolio Total: $11267702.59
# Portfolio appreciates by 12.7 %
#
#
# Equity is valued at: $3801825.83
# Cash Position: $8477608.69
# Portfolio Total: $12279434.52
# Portfolio appreciates by 22.8 %
#
#
# Equity is valued at: $3140551.11
# Cash Position: $8487214.75
# Portfolio Total: $11627765.87
# Portfolio appreciates by 16.3 %
#
#
# Equity is valued at: $1643639.30
# Cash Position: $9409423.04
# Portfolio Total: $11053062.34
# Portfolio appreciates by 10.5 %
#
#
# Equity is valued at: $7893793.48
# Cash Position: $8469556.90
# Portfolio Total: $16363350.38
# Portfolio appreciates by 63.6 %
#
#
# Equity is valued at: $922357.60
# Cash Position: $12220490.66
# Portfolio Total: $13142848.27
# Portfolio appreciates by 31.4 %
#
#
# Equity is valued at: $1797118.73
# Cash Position: $8209519.58
# Portfolio Total: $10006638.31
# Portfolio appreciates by 0.1 %
#
#
# Equity is valued at: $2445100.48
# Cash Position: $8501735.01
# Portfolio Total: $10946835.49
# Portfolio appreciates by 9.5 %
#
#
# Equity is valued at: $2393051.67
# Cash Position: $7642763.01
# Portfolio Total: $10035814.68
# Portfolio appreciates by 0.4 %
#
#
# Equity is valued at: $3719066.20
# Cash Position: $8607486.81
# Portfolio Total: $12326553.02
# Portfolio appreciates by 23.3 %
#
#
# Equity is valued at: $4131841.35
# Cash Position: $8002899.86
# Portfolio Total: $12134741.21
# Portfolio appreciates by 21.3 %
#
#
# Equity is valued at: $3630108.28
# Cash Position: $7129494.89
# Portfolio Total: $10759603.17
# Portfolio appreciates by 7.6 %
#
#
# Equity is valued at: $7708992.27
# Cash Position: $8172617.41
# Portfolio Total: $15881609.69
# Portfolio appreciates by 58.8 %
#
#
# Equity is valued at: $5529938.20
# Cash Position: $8089940.82
# Portfolio Total: $13619879.01
# Portfolio appreciates by 36.2 %
#
#
# Equity is valued at: $1500992.47
# Cash Position: $7513518.56
# Portfolio Total: $9014511.02
# Portfolio appreciates by -9.9 %
#
#
# Equity is valued at: $2160692.42
# Cash Position: $8293504.65
# Portfolio Total: $10454197.07
# Portfolio appreciates by 4.5 %
#
#
# Equity is valued at: $1377946.24
# Cash Position: $8830278.67
# Portfolio Total: $10208224.91
# Portfolio appreciates by 2.1 %
#
#
# Equity is valued at: $2898143.47
# Cash Position: $9050031.69
# Portfolio Total: $11948175.15
# Portfolio appreciates by 19.5 %
#
#
# Equity is valued at: $2006689.41
# Cash Position: $7996969.21
# Portfolio Total: $10003658.62
# Portfolio appreciates by 0.0 %
#
#
# Equity is valued at: $995355.60
# Cash Position: $11605225.92
# Portfolio Total: $12600581.52
# Portfolio appreciates by 26.0 %
#
#
# Equity is valued at: $3170509.14
# Cash Position: $11221400.05
# Portfolio Total: $14391909.19
# Portfolio appreciates by 43.9 %
#
#
# Equity is valued at: $2180565.01
# Cash Position: $9180259.85
# Portfolio Total: $11360824.85
# Portfolio appreciates by 13.6 %
#
#
# Equity is valued at: $2009383.37
# Cash Position: $8933422.80
# Portfolio Total: $10942806.17
# Portfolio appreciates by 9.4 %
#
#
# Equity is valued at: $8211086.84
# Cash Position: $7834904.42
# Portfolio Total: $16045991.26
# Portfolio appreciates by 60.5 %
#
#
# Equity is valued at: $8594386.47
# Cash Position: $6882179.86
# Portfolio Total: $15476566.33
# Portfolio appreciates by 54.8 %
#
#
# Equity is valued at: $3142483.20
# Cash Position: $7460252.06
# Portfolio Total: $10602735.26
# Portfolio appreciates by 6.0 %
#
#
# Equity is valued at: $9197812.63
# Cash Position: $7754259.62
# Portfolio Total: $16952072.25
# Portfolio appreciates by 69.5 %
#
#
# Equity is valued at: $10675410.27
# Cash Position: $7970951.27
# Portfolio Total: $18646361.54
# Portfolio appreciates by 86.5 %
#
#
# Equity is valued at: $3723432.02
# Cash Position: $8518481.61
# Portfolio Total: $12241913.63
# Portfolio appreciates by 22.4 %
#
#
# Equity is valued at: $3493105.18
# Cash Position: $8774763.77
# Portfolio Total: $12267868.95
# Portfolio appreciates by 22.7 %
#
#
# Equity is valued at: $1538501.75
# Cash Position: $8381359.38
# Portfolio Total: $9919861.13
# Portfolio appreciates by -0.8 %
#
#
# Equity is valued at: $3345706.39
# Cash Position: $8292335.34
# Portfolio Total: $11638041.74
# Portfolio appreciates by 16.4 %
#
#
# Equity is valued at: $2989237.42
# Cash Position: $7879489.82
# Portfolio Total: $10868727.23
# Portfolio appreciates by 8.7 %
#
#
# Equity is valued at: $1245667.51
# Cash Position: $7683566.45
# Portfolio Total: $8929233.96
# Portfolio appreciates by -10.7 %
#
#
# Equity is valued at: $3027907.97
# Cash Position: $8552012.82
# Portfolio Total: $11579920.78
# Portfolio appreciates by 15.8 %
#
#
# Equity is valued at: $4345431.65
# Cash Position: $8524240.64
# Portfolio Total: $12869672.29
print ("Strategy One Return - mean:{:.1f}%, std:{:.1f}%".format(statistics.mean(returns),statistics.stdev(returns)))
plt.figure(figsize=(10, 6))
num_bins = 20
plt.hist(returns,num_bins)
plt.xlabel('Portfolio Return (%)')
plt.ylabel("Frequency")
plt.title("Strategy One - Return Distribution")

plt.axvline(x=118.613, color="red", linestyle='--')
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# Strategy One Return - mean:24.1%, std:25.4%

# %% [markdown]
# # Implement Strategy Two - Prune Losers & Reinvest in Winners

# %%
num_iterations = 2000
returns = []
debug = False

for i in range(num_iterations):
    
    # Execute Strategy Two 

    portfolio = {}  # for storing portfolio info
    last = None   # to save a copy of the portfolio prior to rebalancing
    cash = START  # Start with $10M in cash

    for date, num_tickers, rebalance_period in zip(end_dates,portfolio_sizes, rebalance_periods):

        if debug:
            print('Portfolio: {}'.format(date))
        start, end = rebalance_period

        if last is None:  # Build the portfolio by investing starter cash evenly in a number of tickers

            if debug:
                print("Invest Evenly into {} tickers!".format(num_tickers))

            portfolio[date] = {}
            # Randomly select a set number of tickers from the prospect list (SHOTGUN)
            portfolio[date]['tickers'] = random_select(list(prospects[date].index), num_tickers)  
            portfolio[date]['num_shares'] = [0 for x in portfolio[date]['tickers']]

            # Invest cash evenly between the tickers
            invest = start_cash/num_tickers  
            portfolio[date]['num_shares'] = invest_evenly(portfolio[date]['tickers'], \
                                                         portfolio[date]['num_shares'], \
                                                         invest, start, end, debug=debug)

            last = portfolio[date]   # Save a copy of the portfolio for later iterations
            cash = 0  # No more cash left

        else:   # Rebalance portfolio - Let Winners run, Cut Losers Loose

            if debug:
                print("Let Winners run!")

            portfolio[date] = {}
            new_portfolio = {}
            loser_tickers = []
            loser_holdings = []

            # If a ticker in the portfolio is on the new prospect list, keep it as a Winner.
            # If a ticker is not on the new prospect list, sell its position for cash
            winners, losers = identify_winners(last['tickers'], list(prospects[date].index))
            
            if len(losers) is not 0:  # if there are losers
                
                # create new portfolio by pruning the losers
                new_portfolio, loser_tickers,loser_holdings = prune_losers(last, losers, debug=debug)  

                # Liquidate Losers for cash during rebalance period
                liquidation = liquidate(loser_tickers, loser_holdings, start, end, debug=debug)
                cash += liquidation
            else:
                new_portfolio = last  # no change to the portfolio
            
            if debug:
                print('Winners: {}'.format(winners))
                print('Losers: {}'.format(losers))
                print('Cash harvested from Losers: ${:.2f}'.format(liquidation))   

           
            if cash > 0 and len(new_portfolio['tickers']) > 0:
                # If there is cash left over and there are winners left, invest it evenly into the winners
                
                num_winners = len(new_portfolio['tickers'])
                if debug:
                    print("Invest ${:.2f} into {} Winners!".format(cash, num_winners))

                # Invest cash evenly between the tickers
                invest = cash/num_winners  
                new_portfolio['num_shares'] = invest_evenly(new_portfolio['tickers'], \
                                                             new_portfolio['num_shares'], \
                                                             invest, start, end, debug=debug)
                cash = 0  # No more cash left

            # Merge Newbies and Winners into final portfolio        
            # portfolio[date]['tickers'] = winner_tickers + newbie_tickers
            # portfolio[date]['num_shares'] = winner_holdings + newbie_holdings
            portfolio[date] = new_portfolio
            
            last = portfolio[date].copy()   # Save portfolio for later iterations

    # Calculate value of the stock holdings on target date
    equity = portfolio_value(last['tickers'], last['num_shares'], target_date)
    total = equity + cash
    
    # Calculate and save portfolio return
    portfolio_return = (total/start_cash-1)*100
    returns.append(portfolio_return)

    print('Equity is valued at: ${:.2f}'.format(equity))
    print('Cash Position: ${:.2f}'.format(cash))
    print('Portfolio Total: ${:.2f}'.format(total))
    print('Portfolio appreciates by {:.1f} %'.format(portfolio_return))
    print('\n')
# Out:
# Equity is valued at: $39445565.37
# Cash Position: $0.00
# Portfolio Total: $39445565.37
# Portfolio appreciates by 294.5 %
#
#
# Equity is valued at: $28861240.28
# Cash Position: $0.00
# Portfolio Total: $28861240.28
# Portfolio appreciates by 188.6 %
#
#
# Equity is valued at: $19464184.48
# Cash Position: $0.00
# Portfolio Total: $19464184.48
# Portfolio appreciates by 94.6 %
#
#
# Equity is valued at: $10214070.20
# Cash Position: $0.00
# Portfolio Total: $10214070.20
# Portfolio appreciates by 2.1 %
#
#
# Equity is valued at: $17640112.93
# Cash Position: $0.00
# Portfolio Total: $17640112.93
# Portfolio appreciates by 76.4 %
#
#
# Equity is valued at: $12788537.26
# Cash Position: $0.00
# Portfolio Total: $12788537.26
# Portfolio appreciates by 27.9 %
#
#
# Equity is valued at: $11436176.53
# Cash Position: $0.00
# Portfolio Total: $11436176.53
# Portfolio appreciates by 14.4 %
#
#
# Equity is valued at: $18950076.02
# Cash Position: $0.00
# Portfolio Total: $18950076.02
# Portfolio appreciates by 89.5 %
#
#
# Equity is valued at: $10059044.59
# Cash Position: $0.00
# Portfolio Total: $10059044.59
# Portfolio appreciates by 0.6 %
#
#
# Equity is valued at: $14406331.51
# Cash Position: $0.00
# Portfolio Total: $14406331.51
# Portfolio appreciates by 44.1 %
#
#
# Equity is valued at: $21867941.59
# Cash Position: $0.00
# Portfolio Total: $21867941.59
# Portfolio appreciates by 118.7 %
#
#
# Equity is valued at: $9289541.24
# Cash Position: $0.00
# Portfolio Total: $9289541.24
# Portfolio appreciates by -7.1 %
#
#
# Equity is valued at: $11254780.86
# Cash Position: $0.00
# Portfolio Total: $11254780.86
# Portfolio appreciates by 12.5 %
#
#
# Equity is valued at: $15999357.37
# Cash Position: $0.00
# Portfolio Total: $15999357.37
# Portfolio appreciates by 60.0 %
#
#
# Equity is valued at: $31720574.64
# Cash Position: $0.00
# Portfolio Total: $31720574.64
# Portfolio appreciates by 217.2 %
#
#
# Equity is valued at: $12284235.57
# Cash Position: $0.00
# Portfolio Total: $12284235.57
# Portfolio appreciates by 22.8 %
#
#
# Equity is valued at: $10613755.97
# Cash Position: $0.00
# Portfolio Total: $10613755.97
# Portfolio appreciates by 6.1 %
#
#
# Equity is valued at: $17286129.42
# Cash Position: $0.00
# Portfolio Total: $17286129.42
# Portfolio appreciates by 72.9 %
#
#
# Equity is valued at: $19068916.16
# Cash Position: $0.00
# Portfolio Total: $19068916.16
# Portfolio appreciates by 90.7 %
#
#
# Equity is valued at: $13561927.01
# Cash Position: $0.00
# Portfolio Total: $13561927.01
# Portfolio appreciates by 35.6 %
#
#
# Equity is valued at: $17309575.79
# Cash Position: $0.00
# Portfolio Total: $17309575.79
# Portfolio appreciates by 73.1 %
#
#
# Equity is valued at: $18452532.03
# Cash Position: $0.00
# Portfolio Total: $18452532.03
# Portfolio appreciates by 84.5 %
#
#
# Equity is valued at: $12832002.05
# Cash Position: $0.00
# Portfolio Total: $12832002.05
# Portfolio appreciates by 28.3 %
#
#
# Equity is valued at: $19206349.72
# Cash Position: $0.00
# Portfolio Total: $19206349.72
# Portfolio appreciates by 92.1 %
#
#
# Equity is valued at: $46058448.40
# Cash Position: $0.00
# Portfolio Total: $46058448.40
# Portfolio appreciates by 360.6 %
#
#
# Equity is valued at: $15120794.07
# Cash Position: $0.00
# Portfolio Total: $15120794.07
# Portfolio appreciates by 51.2 %
#
#
# Equity is valued at: $12439733.12
# Cash Position: $0.00
# Portfolio Total: $12439733.12
# Portfolio appreciates by 24.4 %
#
#
# Equity is valued at: $23375911.13
# Cash Position: $0.00
# Portfolio Total: $23375911.13
# Portfolio appreciates by 133.8 %
#
#
# Equity is valued at: $11292771.11
# Cash Position: $0.00
# Portfolio Total: $11292771.11
# Portfolio appreciates by 12.9 %
#
#
# Equity is valued at: $18402880.91
# Cash Position: $0.00
# Portfolio Total: $18402880.91
# Portfolio appreciates by 84.0 %
#
#
# Equity is valued at: $24616012.36
# Cash Position: $0.00
# Portfolio Total: $24616012.36
# Portfolio appreciates by 146.2 %
#
#
# Equity is valued at: $17571827.88
# Cash Position: $0.00
# Portfolio Total: $17571827.88
# Portfolio appreciates by 75.7 %
#
#
# Equity is valued at: $15839158.70
# Cash Position: $0.00
# Portfolio Total: $15839158.70
# Portfolio appreciates by 58.4 %
#
#
# Equity is valued at: $28633326.40
# Cash Position: $0.00
# Portfolio Total: $28633326.40
# Portfolio appreciates by 186.3 %
#
#
# Equity is valued at: $15323893.20
# Cash Position: $0.00
# Portfolio Total: $15323893.20
# Portfolio appreciates by 53.2 %
#
#
# Equity is valued at: $29591280.29
# Cash Position: $0.00
# Portfolio Total: $29591280.29
# Portfolio appreciates by 195.9 %
#
#
# Equity is valued at: $14759458.98
# Cash Position: $0.00
# Portfolio Total: $14759458.98
# Portfolio appreciates by 47.6 %
#
#
# Equity is valued at: $13847116.91
# Cash Position: $0.00
# Portfolio Total: $13847116.91
# Portfolio appreciates by 38.5 %
#
#
# Equity is valued at: $15759066.78
# Cash Position: $0.00
# Portfolio Total: $15759066.78
# Portfolio appreciates by 57.6 %
#
#
# Equity is valued at: $13621632.93
# Cash Position: $0.00
# Portfolio Total: $13621632.93
# Portfolio appreciates by 36.2 %
#
#
# Equity is valued at: $15076664.08
# Cash Position: $0.00
# Portfolio Total: $15076664.08
# Portfolio appreciates by 50.8 %
#
#
# Equity is valued at: $14106900.81
# Cash Position: $0.00
# Portfolio Total: $14106900.81
# Portfolio appreciates by 41.1 %
#
#
# Equity is valued at: $13292681.08
# Cash Position: $0.00
# Portfolio Total: $13292681.08
# Portfolio appreciates by 32.9 %
#
#
# Equity is valued at: $30395039.48
# Cash Position: $0.00
# Portfolio Total: $30395039.48
# Portfolio appreciates by 204.0 %
#
#
# Equity is valued at: $24025919.09
# Cash Position: $0.00
# Portfolio Total: $24025919.09
# Portfolio appreciates by 140.3 %
#
#
# Equity is valued at: $15556671.79
# Cash Position: $0.00
# Portfolio Total: $15556671.79
# Portfolio appreciates by 55.6 %
#
#
# Equity is valued at: $12374673.77
# Cash Position: $0.00
# Portfolio Total: $12374673.77
# Portfolio appreciates by 23.7 %
#
#
# Equity is valued at: $12576556.91
# Cash Position: $0.00
# Portfolio Total: $12576556.91
# Portfolio appreciates by 25.8 %
#
#
# Equity is valued at: $37347103.91
# Cash Position: $0.00
# Portfolio Total: $37347103.91
# Portfolio appreciates by 273.5 %
#
#
# Equity is valued at: $12421779.47
# Cash Position: $0.00
# Portfolio Total: $12421779.47
# Portfolio appreciates by 24.2 %
#
#
# Equity is valued at: $25378210.90
# Cash Position: $0.00
# Portfolio Total: $25378210.90
# Portfolio appreciates by 153.8 %
#
#
# Equity is valued at: $19176516.95
# Cash Position: $0.00
# Portfolio Total: $19176516.95
# Portfolio appreciates by 91.8 %
#
#
# Equity is valued at: $20211364.89
# Cash Position: $0.00
# Portfolio Total: $20211364.89
# Portfolio appreciates by 102.1 %
#
#
# Equity is valued at: $18038464.26
# Cash Position: $0.00
# Portfolio Total: $18038464.26
# Portfolio appreciates by 80.4 %
#
#
# Equity is valued at: $21801737.82
# Cash Position: $0.00
# Portfolio Total: $21801737.82
# Portfolio appreciates by 118.0 %
#
#
# Equity is valued at: $19409764.33
# Cash Position: $0.00
# Portfolio Total: $19409764.33
# Portfolio appreciates by 94.1 %
#
#
# Equity is valued at: $10335184.59
# Cash Position: $0.00
# Portfolio Total: $10335184.59
# Portfolio appreciates by 3.4 %
#
#
# Equity is valued at: $23464965.58
# Cash Position: $0.00
# Portfolio Total: $23464965.58
# Portfolio appreciates by 134.6 %
#
#
# Equity is valued at: $21686750.46
# Cash Position: $0.00
# Portfolio Total: $21686750.46
# Portfolio appreciates by 116.9 %
#
#
# Equity is valued at: $10216086.10
# Cash Position: $0.00
# Portfolio Total: $10216086.10
# Portfolio appreciates by 2.2 %
#
#
# Equity is valued at: $18088511.46
# Cash Position: $0.00
# Portfolio Total: $18088511.46
# Portfolio appreciates by 80.9 %
#
#
# Equity is valued at: $10319412.86
# Cash Position: $0.00
# Portfolio Total: $10319412.86
# Portfolio appreciates by 3.2 %
#
#
# Equity is valued at: $16424611.47
# Cash Position: $0.00
# Portfolio Total: $16424611.47
# Portfolio appreciates by 64.2 %
#
#
# Equity is valued at: $12882956.97
# Cash Position: $0.00
# Portfolio Total: $12882956.97
# Portfolio appreciates by 28.8 %
#
#
# Equity is valued at: $10477694.32
# Cash Position: $0.00
# Portfolio Total: $10477694.32
# Portfolio appreciates by 4.8 %
#
#
# Equity is valued at: $11977645.12
# Cash Position: $0.00
# Portfolio Total: $11977645.12
# Portfolio appreciates by 19.8 %
#
#
# Equity is valued at: $14633734.76
# Cash Position: $0.00
# Portfolio Total: $14633734.76
# Portfolio appreciates by 46.3 %
#
#
# Equity is valued at: $11962060.11
# Cash Position: $0.00
# Portfolio Total: $11962060.11
# Portfolio appreciates by 19.6 %
#
#
# Equity is valued at: $13687334.32
# Cash Position: $0.00
# Portfolio Total: $13687334.32
# Portfolio appreciates by 36.9 %
# Equity is valued at: $12124469.56
# Cash Position: $0.00
# Portfolio Total: $12124469.56
# Portfolio appreciates by 21.2 %
#
#
# Equity is valued at: $17834377.15
# Cash Position: $0.00
# Portfolio Total: $17834377.15
# Portfolio appreciates by 78.3 %
#
#
# Equity is valued at: $18377228.65
# Cash Position: $0.00
# Portfolio Total: $18377228.65
# Portfolio appreciates by 83.8 %
#
#
# Equity is valued at: $22895340.31
# Cash Position: $0.00
# Portfolio Total: $22895340.31
# Portfolio appreciates by 129.0 %
#
#
# Equity is valued at: $10705925.92
# Cash Position: $0.00
# Portfolio Total: $10705925.92
# Portfolio appreciates by 7.1 %
#
#
# Equity is valued at: $17398048.59
# Cash Position: $0.00
# Portfolio Total: $17398048.59
# Portfolio appreciates by 74.0 %
#
#
# Equity is valued at: $11211731.44
# Cash Position: $0.00
# Portfolio Total: $11211731.44
# Portfolio appreciates by 12.1 %
#
#
# Equity is valued at: $17940172.71
# Cash Position: $0.00
# Portfolio Total: $17940172.71
# Portfolio appreciates by 79.4 %
#
#
# Equity is valued at: $15292803.62
# Cash Position: $0.00
# Portfolio Total: $15292803.62
# Portfolio appreciates by 52.9 %
#
#
# Equity is valued at: $10748693.99
# Cash Position: $0.00
# Portfolio Total: $10748693.99
# Portfolio appreciates by 7.5 %
#
#
# Equity is valued at: $29953845.46
# Cash Position: $0.00
# Portfolio Total: $29953845.46
# Portfolio appreciates by 199.5 %
#
#
# Equity is valued at: $16467223.76
# Cash Position: $0.00
# Portfolio Total: $16467223.76
# Portfolio appreciates by 64.7 %
#
#
# Equity is valued at: $27925996.11
# Cash Position: $0.00
# Portfolio Total: $27925996.11
# Portfolio appreciates by 179.3 %
#
#
# Equity is valued at: $18093519.51
# Cash Position: $0.00
# Portfolio Total: $18093519.51
# Portfolio appreciates by 80.9 %
#
#
# Equity is valued at: $12555121.37
# Cash Position: $0.00
# Portfolio Total: $12555121.37
# Portfolio appreciates by 25.6 %
#
#
# Equity is valued at: $72078494.73
# Cash Position: $0.00
# Portfolio Total: $72078494.73
# Portfolio appreciates by 620.8 %
#
#
# Equity is valued at: $20298276.17
# Cash Position: $0.00
# Portfolio Total: $20298276.17
# Portfolio appreciates by 103.0 %
#
#
# Equity is valued at: $61518233.41
# Cash Position: $0.00
# Portfolio Total: $61518233.41
# Portfolio appreciates by 515.2 %
#
#
# Equity is valued at: $27158350.04
# Cash Position: $0.00
# Portfolio Total: $27158350.04
# Portfolio appreciates by 171.6 %
#
#
# Equity is valued at: $19465255.76
# Cash Position: $0.00
# Portfolio Total: $19465255.76
# Portfolio appreciates by 94.7 %
#
#
# Equity is valued at: $13566707.53
# Cash Position: $0.00
# Portfolio Total: $13566707.53
# Portfolio appreciates by 35.7 %
#
#
# Equity is valued at: $17244841.58
# Cash Position: $0.00
# Portfolio Total: $17244841.58
# Portfolio appreciates by 72.4 %
#
#
# Equity is valued at: $23266034.65
# Cash Position: $0.00
# Portfolio Total: $23266034.65
# Portfolio appreciates by 132.7 %
#
#
# Equity is valued at: $10863563.83
# Cash Position: $0.00
# Portfolio Total: $10863563.83
# Portfolio appreciates by 8.6 %
#
#
# Equity is valued at: $11803685.76
# Cash Position: $0.00
# Portfolio Total: $11803685.76
# Portfolio appreciates by 18.0 %
#
#
# Equity is valued at: $22041731.66
# Cash Position: $0.00
# Portfolio Total: $22041731.66
# Portfolio appreciates by 120.4 %
#
#
# Equity is valued at: $13648287.75
# Cash Position: $0.00
# Portfolio Total: $13648287.75
# Portfolio appreciates by 36.5 %
#
#
# Equity is valued at: $25879686.52
# Cash Position: $0.00
# Portfolio Total: $25879686.52
# Portfolio appreciates by 158.8 %
#
#
# Equity is valued at: $14165632.63
# Cash Position: $0.00
# Portfolio Total: $14165632.63
# Portfolio appreciates by 41.7 %
#
#
# Equity is valued at: $9789731.79
# Cash Position: $0.00
# Portfolio Total: $9789731.79
# Portfolio appreciates by -2.1 %
#
#
# Equity is valued at: $20651375.18
# Cash Position: $0.00
# Portfolio Total: $20651375.18
# Portfolio appreciates by 106.5 %
#
#
# Equity is valued at: $14471304.29
# Cash Position: $0.00
# Portfolio Total: $14471304.29
# Portfolio appreciates by 44.7 %
#
#
# Equity is valued at: $19929927.38
# Cash Position: $0.00
# Portfolio Total: $19929927.38
# Portfolio appreciates by 99.3 %
#
#
# Equity is valued at: $11704648.63
# Cash Position: $0.00
# Portfolio Total: $11704648.63
# Portfolio appreciates by 17.0 %
#
#
# Equity is valued at: $9534047.51
# Cash Position: $0.00
# Portfolio Total: $9534047.51
# Portfolio appreciates by -4.7 %
#
#
# Equity is valued at: $18234643.78
# Cash Position: $0.00
# Portfolio Total: $18234643.78
# Portfolio appreciates by 82.3 %
#
#
# Equity is valued at: $15651397.17
# Cash Position: $0.00
# Portfolio Total: $15651397.17
# Portfolio appreciates by 56.5 %
#
#
# Equity is valued at: $13718777.88
# Cash Position: $0.00
# Portfolio Total: $13718777.88
# Portfolio appreciates by 37.2 %
#
#
# Equity is valued at: $15806757.54
# Cash Position: $0.00
# Portfolio Total: $15806757.54
# Portfolio appreciates by 58.1 %
#
#
# Equity is valued at: $13573124.83
# Cash Position: $0.00
# Portfolio Total: $13573124.83
# Portfolio appreciates by 35.7 %
#
#
# Equity is valued at: $13673353.63
# Cash Position: $0.00
# Portfolio Total: $13673353.63
# Portfolio appreciates by 36.7 %
#
#
# Equity is valued at: $23264245.64
# Cash Position: $0.00
# Portfolio Total: $23264245.64
# Portfolio appreciates by 132.6 %
#
#
# Equity is valued at: $14849391.04
# Cash Position: $0.00
# Portfolio Total: $14849391.04
# Portfolio appreciates by 48.5 %
#
#
# Equity is valued at: $12106925.31
# Cash Position: $0.00
# Portfolio Total: $12106925.31
# Equity is valued at: $10276444.73
# Cash Position: $0.00
# Portfolio Total: $10276444.73
# Portfolio appreciates by 2.8 %
#
#
# Equity is valued at: $12305757.51
# Cash Position: $0.00
# Portfolio Total: $12305757.51
# Portfolio appreciates by 23.1 %
#
#
# Equity is valued at: $17763463.19
# Cash Position: $0.00
# Portfolio Total: $17763463.19
# Portfolio appreciates by 77.6 %
#
#
# Equity is valued at: $15420324.10
# Cash Position: $0.00
# Portfolio Total: $15420324.10
# Portfolio appreciates by 54.2 %
#
#
# Equity is valued at: $14022916.03
# Cash Position: $0.00
# Portfolio Total: $14022916.03
# Portfolio appreciates by 40.2 %
#
#
# Equity is valued at: $23208959.97
# Cash Position: $0.00
# Portfolio Total: $23208959.97
# Portfolio appreciates by 132.1 %
#
#
# Equity is valued at: $12078005.05
# Cash Position: $0.00
# Portfolio Total: $12078005.05
# Portfolio appreciates by 20.8 %
#
#
# Equity is valued at: $20873567.25
# Cash Position: $0.00
# Portfolio Total: $20873567.25
# Portfolio appreciates by 108.7 %
#
#
# Equity is valued at: $33866307.52
# Cash Position: $0.00
# Portfolio Total: $33866307.52
# Portfolio appreciates by 238.7 %
#
#
# Equity is valued at: $27651368.45
# Cash Position: $0.00
# Portfolio Total: $27651368.45
# Portfolio appreciates by 176.5 %
#
#
# Equity is valued at: $11600860.43
# Cash Position: $0.00
# Portfolio Total: $11600860.43
# Portfolio appreciates by 16.0 %
#
#
# Equity is valued at: $34523016.16
# Cash Position: $0.00
# Portfolio Total: $34523016.16
# Portfolio appreciates by 245.2 %
#
#
# Equity is valued at: $11564266.92
# Cash Position: $0.00
# Portfolio Total: $11564266.92
# Portfolio appreciates by 15.6 %
#
#
# Equity is valued at: $16104533.80
# Cash Position: $0.00
# Portfolio Total: $16104533.80
# Portfolio appreciates by 61.0 %
#
#
# Equity is valued at: $9536849.25
# Cash Position: $0.00
# Portfolio Total: $9536849.25
# Portfolio appreciates by -4.6 %
#
#
# Equity is valued at: $14829761.45
# Cash Position: $0.00
# Portfolio Total: $14829761.45
# Portfolio appreciates by 48.3 %
#
#
# Equity is valued at: $12435240.16
# Cash Position: $0.00
# Portfolio Total: $12435240.16
# Portfolio appreciates by 24.4 %
#
#
# Equity is valued at: $11923805.15
# Cash Position: $0.00
# Portfolio Total: $11923805.15
# Portfolio appreciates by 19.2 %
#
#
# Equity is valued at: $12204165.20
# Cash Position: $0.00
# Portfolio Total: $12204165.20
# Portfolio appreciates by 22.0 %
#
#
# Equity is valued at: $12879531.50
# Cash Position: $0.00
# Portfolio Total: $12879531.50
# Portfolio appreciates by 28.8 %
#
#
# Equity is valued at: $15996037.49
# Cash Position: $0.00
# Portfolio Total: $15996037.49
# Portfolio appreciates by 60.0 %
#
#
# Equity is valued at: $9860184.61
# Cash Position: $0.00
# Portfolio Total: $9860184.61
# Portfolio appreciates by -1.4 %
#
#
# Equity is valued at: $22993044.00
# Cash Position: $0.00
# Portfolio Total: $22993044.00
# Portfolio appreciates by 129.9 %
#
#
# Equity is valued at: $24398029.08
# Cash Position: $0.00
# Portfolio Total: $17376889.00
# Portfolio appreciates by 73.8 %
#
#
# Equity is valued at: $20575018.89
# Cash Position: $0.00
# Portfolio Total: $20575018.89
# Portfolio appreciates by 105.8 %
#
#
# Equity is valued at: $12428464.80
# Cash Position: $0.00
# Portfolio Total: $12428464.80
# Portfolio appreciates by 24.3 %
# Equity is valued at: $19816739.16
# Cash Position: $0.00
# Portfolio Total: $19816739.16
# Portfolio appreciates by 98.2 %
#
#
# Equity is valued at: $14261194.95
# Cash Position: $0.00
# Portfolio Total: $14261194.95
# Portfolio appreciates by 42.6 %
#
#
# Equity is valued at: $14123070.85
# Cash Position: $0.00
# Portfolio Total: $14123070.85
# Portfolio appreciates by 41.2 %
#
#
# Equity is valued at: $13734234.86
# Cash Position: $0.00
# Portfolio Total: $13734234.86
# Portfolio appreciates by 37.3 %
#
#
# Equity is valued at: $15719402.06
# Cash Position: $0.00
# Portfolio Total: $15719402.06
# Portfolio appreciates by 57.2 %
#
#
# Equity is valued at: $7209229.73
# Cash Position: $0.00
# Portfolio Total: $7209229.73
# Portfolio appreciates by -27.9 %
#
#
# Equity is valued at: $11740009.14
# Cash Position: $0.00
# Portfolio Total: $11740009.14
# Portfolio appreciates by 17.4 %
#
#
# Equity is valued at: $10521664.63
# Cash Position: $0.00
# Portfolio Total: $10521664.63
# Portfolio appreciates by 5.2 %
#
#
# Equity is valued at: $11894695.41
# Cash Position: $0.00
# Portfolio Total: $11894695.41
# Portfolio appreciates by 18.9 %
#
#
# Equity is valued at: $15113808.35
# Cash Position: $0.00
# Portfolio Total: $15113808.35
# Portfolio appreciates by 51.1 %
#
#
# Equity is valued at: $11575085.08
# Cash Position: $0.00
# Portfolio Total: $11575085.08
# Portfolio appreciates by 15.8 %
#
#
# Equity is valued at: $11249462.45
# Cash Position: $0.00
# Portfolio Total: $11249462.45
# Portfolio appreciates by 12.5 %
#
#
# Equity is valued at: $19599275.86
# Cash Position: $0.00
# Portfolio Total: $19599275.86
# Portfolio appreciates by 96.0 %
#
#
# Equity is valued at: $17781522.72
# Cash Position: $0.00
# Portfolio Total: $17781522.72
# Portfolio appreciates by 77.8 %
#
#
# Equity is valued at: $12233054.99
# Cash Position: $0.00
# Portfolio Total: $12233054.99
# Portfolio appreciates by 22.3 %
#
#
# Equity is valued at: $26382820.77
# Cash Position: $0.00
# Portfolio Total: $26382820.77
# Portfolio appreciates by 163.8 %
#
#
# Equity is valued at: $16383008.12
# Cash Position: $0.00
# Portfolio Total: $16383008.12
# Portfolio appreciates by 63.8 %
#
#
# Equity is valued at: $19861242.34
# Cash Position: $0.00
# Portfolio Total: $19861242.34
# Portfolio appreciates by 98.6 %
#
#
# Equity is valued at: $18430762.47
# Cash Position: $0.00
# Portfolio Total: $18430762.47
# Portfolio appreciates by 84.3 %
#
#
# Equity is valued at: $20291453.51
# Cash Position: $0.00
# Portfolio Total: $20291453.51
# Portfolio appreciates by 102.9 %
#
#
# Equity is valued at: $16711188.50
# Cash Position: $0.00
# Portfolio Total: $16711188.50
# Portfolio appreciates by 364.3 %
#
#
# Equity is valued at: $14716058.47
# Cash Position: $0.00
# Portfolio Total: $14716058.47
# Portfolio appreciates by 47.2 %
#
#
# Equity is valued at: $18945164.04
# Cash Position: $0.00
# Portfolio Total: $18945164.04
# Portfolio appreciates by 89.5 %
#
#
# Equity is valued at: $59677772.36
# Cash Position: $0.00
# Portfolio Total: $59677772.36
# Portfolio appreciates by 496.8 %
#
#
# Equity is valued at: $13582200.12
# Cash Position: $0.00
# Portfolio Total: $13582200.12
# Portfolio appreciates by 35.8 %
#
#
# Equity is valued at: $13225332.71
# Cash Position: $0.00
# Portfolio Total: $13225332.71
# Portfolio appreciates by 32.3 %
#
#
# Equity is valued at: $19870583.18
# Cash Position: $0.00
# Portfolio Total: $19870583.18
# Portfolio appreciates by 98.7 %
#
#
# Equity is valued at: $24916749.61
# Cash Position: $0.00
# Portfolio Total: $24916749.61
# Portfolio appreciates by 149.2 %
#
#
# Equity is valued at: $10367796.21
# Cash Position: $0.00
# Portfolio Total: $10367796.21
# Portfolio appreciates by 3.7 %
#
#
# Equity is valued at: $32153061.02
# Cash Position: $0.00
# Portfolio Total: $32153061.02
# Portfolio appreciates by 221.5 %
#
#
# Equity is valued at: $51116915.76
# Cash Position: $0.00
# Portfolio Total: $51116915.76
# Portfolio appreciates by 411.2 %
#
#
# Equity is valued at: $12590376.91
# Cash Position: $0.00
# Portfolio Total: $12590376.91
# Portfolio appreciates by 25.9 %
#
#
# Equity is valued at: $15672809.33
# Cash Position: $0.00
# Portfolio Total: $15672809.33
# Portfolio appreciates by 56.7 %
#
#
# Equity is valued at: $11953744.53
# Cash Position: $0.00
# Portfolio Total: $11953744.53
# Portfolio appreciates by 19.5 %
#
#
# Equity is valued at: $13166226.74
# Cash Position: $0.00
# Portfolio Total: $13166226.74
# Portfolio appreciates by 31.7 %
#
#
# Equity is valued at: $16242857.62
# Cash Position: $0.00
# Portfolio Total: $16242857.62
# Portfolio appreciates by 62.4 %
#
#
# Equity is valued at: $13350097.94
# Cash Position: $0.00
# Portfolio Total: $13350097.94
# Portfolio appreciates by 33.5 %
#
#
# Equity is valued at: $14064442.56
# Cash Position: $0.00
# Portfolio Total: $14064442.56
# Portfolio appreciates by 40.6 %
#
#
# Equity is valued at: $19576587.33
# Cash Position: $0.00
# Portfolio Total: $19576587.33
# Portfolio appreciates by 95.8 %
#
#
# Equity is valued at: $17002709.92
# Cash Position: $0.00
# Portfolio Total: $17002709.92
# Portfolio appreciates by 70.0 %
#
#
# Equity is valued at: $23012021.85
# Cash Position: $0.00
# Portfolio Total: $23012021.85
# Portfolio appreciates by 130.1 %
#
#
# Equity is valued at: $16290392.31
# Cash Position: $0.00
# Portfolio Total: $16290392.31
# Portfolio appreciates by 62.9 %
#
#
# Equity is valued at: $18703518.09
# Cash Position: $0.00
# Portfolio Total: $18703518.09
# Portfolio appreciates by 87.0 %
#
#
# Equity is valued at: $16166507.04
# Cash Position: $0.00
# Portfolio Total: $16166507.04
# Portfolio appreciates by 61.7 %
#
#
# Equity is valued at: $20378931.57
# Cash Position: $0.00
# Portfolio Total: $20378931.57
# Portfolio appreciates by 103.8 %
#
#
# Equity is valued at: $41635574.27
# Cash Position: $0.00
# Portfolio Total: $41635574.27
# Portfolio appreciates by 316.4 %
#
#
# Equity is valued at: $25027561.74
# Cash Position: $0.00
# Portfolio Total: $25027561.74
# Portfolio appreciates by 150.3 %
#
#
# Equity is valued at: $12428082.28
# Cash Position: $0.00
# Portfolio Total: $12428082.28
# Portfolio appreciates by 24.3 %
#
#
# Equity is valued at: $12242630.02
# Cash Position: $0.00
# Portfolio Total: $12242630.02
# Portfolio appreciates by 22.4 %
#
#
# Equity is valued at: $14873349.00
# Cash Position: $0.00
# Portfolio Total: $14873349.00
# Portfolio appreciates by 48.7 %
#
#
# Equity is valued at: $21855171.26
# Cash Position: $0.00
# Portfolio Total: $21855171.26
# Portfolio appreciates by 118.6 %
#
#
# Equity is valued at: $14457294.41
# Cash Position: $0.00
# Portfolio Total: $14457294.41
# Portfolio appreciates by 44.6 %
#
#
# Equity is valued at: $22531553.87
# Cash Position: $0.00
# Portfolio Total: $22531553.87
# Portfolio appreciates by 125.3 %
#
#
# Equity is valued at: $18911949.14
# Cash Position: $0.00
# Portfolio Total: $18911949.14
# Portfolio appreciates by 89.1 %
#
#
# Equity is valued at: $10400714.91
# Cash Position: $0.00
# Portfolio Total: $10400714.91
# Portfolio appreciates by 4.0 %
#
#
# Equity is valued at: $17214138.09
# Cash Position: $0.00
# Portfolio Total: $17214138.09
# Portfolio appreciates by 72.1 %
#
#
# Equity is valued at: $15821319.51
# Cash Position: $0.00
# Portfolio Total: $15821319.51
# Portfolio appreciates by 58.2 %
#
#
# Equity is valued at: $20605994.30
# Cash Position: $0.00
# Portfolio Total: $20605994.30
# Portfolio appreciates by 106.1 %
#
#
# Equity is valued at: $16881343.59
# Cash Position: $0.00
# Portfolio Total: $16881343.59
# Portfolio appreciates by 68.8 %
#
#
# Equity is valued at: $19978444.56
# Cash Position: $0.00
# Portfolio Total: $19978444.56
# Portfolio appreciates by 99.8 %
#
#
# Equity is valued at: $15399297.04
# Cash Position: $0.00
# Portfolio Total: $15399297.04
# Portfolio appreciates by 54.0 %
#
#
# Equity is valued at: $15124283.77
# Cash Position: $0.00
# Portfolio Total: $15124283.77
# Portfolio appreciates by 51.2 %
#
#
# Equity is valued at: $12625354.59
# Cash Position: $0.00
# Portfolio Total: $12625354.59
# Portfolio appreciates by 26.3 %
#
#
# Equity is valued at: $6241292.50
# Cash Position: $0.00
# Portfolio Total: $6241292.50
# Portfolio appreciates by -37.6 %
#
#
# Equity is valued at: $15236136.32
# Cash Position: $0.00
# Portfolio Total: $15236136.32
# Portfolio appreciates by 52.4 %
# Equity is valued at: $12550963.74
# Cash Position: $0.00
# Portfolio Total: $12550963.74
# Portfolio appreciates by 25.5 %
#
#
# Equity is valued at: $15192273.61
# Cash Position: $0.00
# Portfolio Total: $15192273.61
# Portfolio appreciates by 51.9 %
#
#
# Equity is valued at: $13503647.21
# Cash Position: $0.00
# Portfolio Total: $13503647.21
# Portfolio appreciates by 35.0 %
#
#
# Equity is valued at: $12778275.88
# Cash Position: $0.00
# Portfolio Total: $12778275.88
# Portfolio appreciates by 27.8 %
#
#
# Equity is valued at: $26785143.57
# Cash Position: $0.00
# Portfolio Total: $26785143.57
# Portfolio appreciates by 167.9 %
#
#
# Equity is valued at: $16229765.10
# Cash Position: $0.00
# Portfolio Total: $16229765.10
# Portfolio appreciates by 62.3 %
#
#
# Equity is valued at: $16792174.45
# Cash Position: $0.00
# Portfolio Total: $16792174.45
# Portfolio appreciates by 67.9 %
#
#
# Equity is valued at: $24773580.93
# Cash Position: $0.00
# Portfolio Total: $24773580.93
# Portfolio appreciates by 147.7 %
#
#
# Equity is valued at: $12648108.13
# Cash Position: $0.00
# Portfolio Total: $12648108.13
# Portfolio appreciates by 26.5 %
#
#
# Equity is valued at: $10467469.01
# Cash Position: $0.00
# Portfolio Total: $10467469.01
# Portfolio appreciates by 4.7 %
#
#
# Equity is valued at: $13950563.64
# Cash Position: $0.00
# Portfolio Total: $13950563.64
# Portfolio appreciates by 39.5 %
#
#
# Equity is valued at: $13351067.76
# Cash Position: $0.00
# Portfolio Total: $13351067.76
# Portfolio appreciates by 33.5 %
#
#
# Equity is valued at: $15536249.69
# Cash Position: $0.00
# Portfolio Total: $15536249.69
# Portfolio appreciates by 55.4 %
#
#
# Equity is valued at: $7272295.96
# Cash Position: $0.00
# Portfolio Total: $7272295.96
# Portfolio appreciates by -27.3 %
#
#
# Equity is valued at: $14029355.45
# Cash Position: $0.00
# Portfolio Total: $14029355.45
# Portfolio appreciates by 40.3 %
#
#
# Equity is valued at: $11809281.37
# Cash Position: $0.00
# Portfolio Total: $11809281.37
# Portfolio appreciates by 18.1 %
#
#
# Equity is valued at: $19252771.12
# Cash Position: $0.00
# Portfolio Total: $19252771.12
# Portfolio appreciates by 92.5 %
#
#
# Equity is valued at: $11107422.70
# Cash Position: $0.00
# Portfolio Total: $11107422.70
# Portfolio appreciates by 11.1 %
#
#
# Equity is valued at: $18743957.13
# Cash Position: $0.00
# Portfolio Total: $18743957.13
# Portfolio appreciates by 87.4 %
#
#
# Equity is valued at: $11083801.09
# Cash Position: $0.00
# Portfolio Total: $11083801.09
# Portfolio appreciates by 10.8 %
#
#
# Equity is valued at: $18834653.31
# Cash Position: $0.00
# Portfolio Total: $18834653.31
# Portfolio appreciates by 88.3 %
#
#
# Equity is valued at: $11830239.33
# Cash Position: $0.00
# Portfolio Total: $11830239.33
# Portfolio appreciates by 18.3 %
#
#
# Equity is valued at: $15540020.45
# Cash Position: $0.00
# Portfolio Total: $15540020.45
# Portfolio appreciates by 55.4 %
#
#
# Equity is valued at: $18849566.97
# Cash Position: $0.00
# Portfolio Total: $18849566.97
# Portfolio appreciates by 88.5 %
#
#
# Equity is valued at: $10091454.65
# Cash Position: $0.00
# Portfolio Total: $10091454.65
# Portfolio appreciates by 0.9 %
#
#
# Equity is valued at: $23539757.33
# Cash Position: $0.00
# Portfolio Total: $23539757.33
# Portfolio appreciates by 135.4 %
#
#
# Equity is valued at: $28266813.19
# Cash Position: $0.00
# Portfolio Total: $28266813.19
# Portfolio appreciates by 182.7 %
#
#
# Equity is valued at: $8714094.08
# Cash Position: $0.00
# Portfolio Total: $8714094.08
# Portfolio appreciates by -12.9 %
#
#
# Equity is valued at: $14604843.31
# Cash Position: $0.00
# Portfolio Total: $14604843.31
# Portfolio appreciates by 46.0 %
#
#
# Equity is valued at: $18990735.56
# Cash Position: $0.00
# Portfolio Total: $18990735.56
# Portfolio appreciates by 89.9 %
#
#
# Equity is valued at: $11304113.03
# Cash Position: $0.00
# Portfolio Total: $11304113.03
# Portfolio appreciates by 13.0 %
#
#
# Equity is valued at: $20871588.23
# Cash Position: $0.00
# Portfolio Total: $20871588.23
# Portfolio appreciates by 108.7 %
#
#
# Equity is valued at: $16477990.14
# Cash Position: $0.00
# Portfolio Total: $16477990.14
# Portfolio appreciates by 64.8 %
#
#
# Equity is valued at: $13211767.39
# Cash Position: $0.00
# Portfolio Total: $13211767.39
# Portfolio appreciates by 32.1 %
#
#
# Equity is valued at: $15104061.90
# Cash Position: $0.00
# Portfolio Total: $15104061.90
# Portfolio appreciates by 51.0 %
#
#
# Equity is valued at: $15689511.07
# Cash Position: $0.00
# Portfolio Total: $15689511.07
# Portfolio appreciates by 56.9 %
#
#
# Equity is valued at: $13557175.44
# Cash Position: $0.00
# Portfolio Total: $13557175.44
# Portfolio appreciates by 35.6 %
#
#
# Equity is valued at: $22854580.22
# Cash Position: $0.00
# Portfolio Total: $22854580.22
# Portfolio appreciates by 128.5 %
#
#
# Equity is valued at: $20046630.85
# Cash Position: $0.00
# Portfolio Total: $20046630.85
# Portfolio appreciates by 100.5 %
#
#
# Equity is valued at: $22222687.49
# Cash Position: $0.00
# Portfolio Total: $22222687.49
# Portfolio appreciates by 122.2 %
#
#
# Equity is valued at: $15812995.35
# Cash Position: $0.00
# Portfolio Total: $15812995.35
# Portfolio appreciates by 58.1 %
#
#
# Equity is valued at: $15185375.83
# Cash Position: $0.00
# Portfolio Total: $15185375.83
# Portfolio appreciates by 51.9 %
#
#
# Equity is valued at: $17406481.93
# Cash Position: $0.00
# Portfolio Total: $17406481.93
# Portfolio appreciates by 74.1 %
#
#
# Equity is valued at: $14918632.36
# Cash Position: $0.00
# Portfolio Total: $14918632.36
# Portfolio appreciates by 49.2 %
#
#
# Equity is valued at: $18339976.81
# Cash Position: $0.00
# Portfolio Total: $18339976.81
# Portfolio appreciates by 83.4 %
#
#
# Equity is valued at: $18407434.45
# Cash Position: $0.00
# Portfolio Total: $18407434.45
# Portfolio appreciates by 84.1 %
#
#
# Equity is valued at: $20674725.39
# Cash Position: $0.00
# Portfolio Total: $20674725.39
# Portfolio appreciates by 106.7 %
#
#
# Equity is valued at: $12018138.04
# Cash Position: $0.00
# Portfolio Total: $12018138.04
# Portfolio appreciates by 20.2 %
#
#
# Equity is valued at: $20112391.16
# Cash Position: $0.00
# Portfolio Total: $20112391.16
# Portfolio appreciates by 101.1 %
#
#
# Equity is valued at: $16608459.82
# Cash Position: $0.00
# Portfolio Total: $16608459.82
# Portfolio appreciates by 66.1 %
#
#
# Equity is valued at: $23025030.35
# Cash Position: $0.00
# Portfolio Total: $23025030.35
# Portfolio appreciates by 130.3 %
#
#
# Equity is valued at: $22905278.33
# Cash Position: $0.00
# Portfolio Total: $22905278.33
# Portfolio appreciates by 129.1 %
#
#
# Equity is valued at: $18227066.75
# Cash Position: $0.00
# Portfolio Total: $18227066.75
# Portfolio appreciates by 82.3 %

# %%
import statistics

print ("Strategy Two Return - mean:{:.1f}%, std:{:.1f}%".format(statistics.mean(returns),statistics.stdev(returns)))
plt.figure(figsize=(10, 6))
num_bins = 20
plt.hist(returns,num_bins)
plt.xlabel('Portfolio Return (%)')
plt.ylabel("Frequency")
plt.title("Strategy Two - Return Distribution")

plt.axvline(x=118.613, color="red", linestyle='--')
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# Strategy Two Return - mean:84.3%, std:97.3%

# %% [markdown]
# # Strategy Three - Prune Losers; Reinvest in Winners and Newbies

# %%
num_iterations = 2000
returns = []
debug = False

for i in range(num_iterations):
    
    # Execute Strategy Three 

    portfolio = {}  # for storing portfolio info
    last = None   # to save a copy of the portfolio prior to rebalancing
    cash = START  # Start with $10M in cash

    for date, num_tickers, rebalance_period in zip(end_dates,portfolio_sizes, rebalance_periods):

        if debug:
            print('Portfolio: {}'.format(date))
        start, end = rebalance_period

        if last is None:  # Build the portfolio by investing starter cash evenly in a number of tickers

            if debug:
                print("Invest Evenly into {} tickers!".format(num_tickers))

            portfolio[date] = {}
            # Randomly select a set number of tickers from the prospect list (SHOTGUN)
            portfolio[date]['tickers'] = random_select(list(prospects[date].index), num_tickers)  
            portfolio[date]['num_shares'] = [0 for x in portfolio[date]['tickers']]

            # Invest cash evenly between the tickers
            invest = start_cash/num_tickers  
            portfolio[date]['num_shares'] = invest_evenly(portfolio[date]['tickers'], \
                                                         portfolio[date]['num_shares'], \
                                                         invest, start, end, debug=debug)

            last = portfolio[date]   # Save a copy of the portfolio for later iterations
            cash = 0  # No more cash left

        else:   # Rebalance portfolio - Let Winners run, Cut Losers Loose

            if debug:
                print("Let Winners run!")

            portfolio[date] = {}
            new_portfolio = {}
            loser_tickers = []
            loser_holdings = []
            newbie_tickers = []
            newbie_holdings = []

            # If a ticker in the portfolio is on the new prospect list, keep it as a Winner.
            # If a ticker is not on the new prospect list, sell its position for cash
            winners, losers = identify_winners(last['tickers'], list(prospects[date].index))
            
            if len(losers) is 0:  # if there are no losers
                new_portfolio = last  # no change to the portfolio
                if debug:
                    print('No change to Portfolio.')
                    print('Winners: {}'.format(winners))
            else:    
                # create new portfolio by pruning the losers
                new_portfolio, loser_tickers,loser_holdings = prune_losers(last, losers, debug=debug)  

                # Liquidate Losers for cash during rebalance period
                cash += liquidate(loser_tickers, loser_holdings, start, end, debug=debug)

                if debug:
                    print('Winners: {}'.format(winners))
                    print('Losers: {}'.format(losers))
                    print('Cash harvested from Losers: ${:.2f}'.format(cash))    
          
                if len(winners) >= num_tickers:
                    # If number of winners exceed the target ticker numbers
                    # Skip investing into newbies, cash will be reinvested into Winners
                    if debug:
                        print("{} Winners. No need for new prospects!".format(len(winners)))

                else:
                    # Pick newbies from prospect list and invest into them.
                    # If there is cash left over, it will be reinvested into Winners
                    
                    num_newbies = num_tickers - len(winners)
                    standard_invest = START/num_tickers  # standard amount to invest per ticker 
                    available_invest = cash/num_newbies   # available amount to invest per ticker

                    if available_invest <= standard_invest:
                        # If available amount per ticker is less than standard amount
                        # Then simply invest what is available
                        invest = available_invest
                        cash = 0  # then there will be no left-over cash
                        if debug:
                            print('No extra cash!')
                    else:
                        # If available amount per ticker is more than standard amount
                        # Then invest the standard amount.
                        invest = standard_invest
                        cash -= invest * num_newbies  # There is left-over cash
                        if debug:
                            print('Extra cash!')

                    # Randomly select new tickers from the prospect list
                    newbie_tickers = random_select(list(prospects[date].index), num_newbies, winners)
                    newbie_holdings = [0 for x in newbie_tickers]

                    newbie_holdings = invest_evenly(newbie_tickers, newbie_holdings, \
                                                             invest, start, end, debug=debug)                  
           
            if cash > 0 and len(new_portfolio['tickers']) > 0:
                # If there is cash left over and there are winners left, invest it evenly into the Winners
                
                num_winners = len(new_portfolio['tickers'])
                if debug:
                    print("Invest ${:.2f} into {} Winners!".format(cash, num_winners))

                # Invest cash evenly between the tickers
                invest = cash/num_winners  
                new_portfolio['num_shares'] = invest_evenly(new_portfolio['tickers'],new_portfolio['num_shares'], \
                                                             invest, start, end, debug=debug)
                cash = 0  # No more cash left

            # Merge Newbies and Winners into final portfolio 
            if debug:
                print('Merge:')
                print('Newbies:{}'.format(newbie_tickers))
                print('Winners:{}'.format(new_portfolio['tickers']))
                print('Num Tickers:{}'.format(len(newbie_tickers)+len(new_portfolio['tickers'])))
            
            portfolio[date]['tickers'] = new_portfolio['tickers'] + newbie_tickers
            portfolio[date]['num_shares'] = new_portfolio['num_shares'] + newbie_holdings
            
            last = portfolio[date].copy()   # Save portfolio for later iterations

    # Calculate value of the stock holdings on target date
    equity = portfolio_value(last['tickers'], last['num_shares'], target_date)
    total = equity + cash
    
    # Calculate and save portfolio return
    portfolio_return = (total/start_cash-1)*100
    returns.append(portfolio_return)

    print('Equity is valued at: ${:.2f}'.format(equity))
    print('Cash Position: ${:.2f}'.format(cash))
    print('Portfolio Total: ${:.2f}'.format(total))
    print('Portfolio appreciates by {:.1f} %'.format(portfolio_return))
    print('\n')
# Out:
# Equity is valued at: $23357687.48
# Cash Position: $0.00
# Portfolio Total: $23357687.48
# Portfolio appreciates by 133.6 %
#
#
# Equity is valued at: $29047681.76
# Cash Position: $0.00
# Portfolio Total: $29047681.76
# Portfolio appreciates by 190.5 %
#
#
# Equity is valued at: $16102052.65
# Cash Position: $0.00
# Portfolio Total: $16102052.65
# Portfolio appreciates by 61.0 %
#
#
# Equity is valued at: $25690295.49
# Cash Position: $0.00
# Portfolio Total: $25690295.49
# Portfolio appreciates by 156.9 %
#
#
# Equity is valued at: $18126637.59
# Portfolio Total: $16866132.58
# Portfolio appreciates by 68.7 %
#
#
# Equity is valued at: $19741963.81
# Cash Position: $0.00
# Portfolio Total: $19741963.81
# Portfolio appreciates by 97.4 %
#
#
# Equity is valued at: $17979909.77
# Cash Position: $0.00
# Portfolio Total: $17979909.77
# Portfolio appreciates by 79.8 %
#
#
# Equity is valued at: $12633700.19
# Cash Position: $0.00
# Portfolio Total: $12633700.19
# Portfolio appreciates by 26.3 %
#
#
# Equity is valued at: $17067197.21
# Cash Position: $0.00
# Portfolio Total: $17067197.21
# Portfolio appreciates by 70.7 %
#
#
# Equity is valued at: $13591805.11
# Cash Position: $0.00
# Portfolio Total: $13591805.11
# Portfolio appreciates by 35.9 %
#
#
# Equity is valued at: $11259931.04
# Cash Position: $0.00
# Portfolio Total: $11259931.04
# Portfolio appreciates by 12.6 %
#
#
# Equity is valued at: $14424245.40
# Cash Position: $0.00
# Portfolio Total: $14424245.40
# Portfolio appreciates by 44.2 %
#
#
# Equity is valued at: $14957244.60
# Cash Position: $0.00
# Portfolio Total: $14957244.60
# Portfolio appreciates by 49.6 %
#
#
# Equity is valued at: $13256824.10
# Cash Position: $0.00
# Portfolio Total: $13256824.10
# Portfolio appreciates by 32.6 %
#
#
# Equity is valued at: $12665941.27
# Cash Position: $0.00
# Portfolio Total: $12665941.27
# Portfolio appreciates by 26.7 %
#
#
# Equity is valued at: $23466385.50
# Cash Position: $0.00
# Portfolio Total: $23466385.50
# Portfolio appreciates by 134.7 %
#
#
# Equity is valued at: $13624206.10
# Cash Position: $0.00
# Portfolio Total: $13624206.10
# Portfolio appreciates by 36.2 %
#
#
# Equity is valued at: $12759808.50
# Cash Position: $0.00
# Portfolio Total: $12759808.50
# Portfolio appreciates by 27.6 %
#
#
# Equity is valued at: $16704570.01
# Cash Position: $0.00
# Portfolio Total: $16704570.01
# Portfolio appreciates by 67.0 %
#
#
# Equity is valued at: $17183490.52
# Cash Position: $0.00
# Portfolio Total: $17183490.52
# Portfolio appreciates by 71.8 %
#
#
# Equity is valued at: $18159368.00
# Cash Position: $0.00
# Portfolio Total: $18159368.00
# Portfolio appreciates by 81.6 %
#
#
# Equity is valued at: $22821052.05
# Cash Position: $0.00
# Portfolio Total: $22821052.05
# Portfolio appreciates by 128.2 %
#
#
# Equity is valued at: $20864317.53
# Cash Position: $0.00
# Portfolio Total: $20864317.53
# Portfolio appreciates by 108.6 %
#
#
# Equity is valued at: $18993162.01
# Cash Position: $0.00
# Portfolio Total: $18993162.01
# Portfolio appreciates by 89.9 %
#
#
# Equity is valued at: $16904813.74
# Cash Position: $0.00
# Portfolio Total: $16904813.74
# Portfolio appreciates by 69.0 %
#
#
# Equity is valued at: $15313365.41
# Cash Position: $0.00
# Portfolio Total: $15313365.41
# Portfolio appreciates by 53.1 %
#
#
# Equity is valued at: $17423131.05
# Cash Position: $0.00
# Portfolio Total: $17423131.05
# Portfolio appreciates by 74.2 %
#
#
# Equity is valued at: $14234406.83
# Cash Position: $0.00
# Portfolio Total: $14234406.83
# Portfolio appreciates by 42.3 %
#
#
# Equity is valued at: $11038042.66
# Cash Position: $0.00
# Portfolio Total: $11038042.66
# Portfolio appreciates by 10.4 %
#
#
# Equity is valued at: $19242667.57
# Cash Position: $0.00
# Portfolio Total: $19242667.57
# Portfolio appreciates by 92.4 %
#
#
# Equity is valued at: $16916397.31
# Cash Position: $0.00
# Portfolio Total: $16916397.31
# Portfolio appreciates by 69.2 %
#
#
# Equity is valued at: $15129177.28
# Cash Position: $0.00
# Portfolio Total: $15129177.28
# Portfolio appreciates by 51.3 %
#
#
# Equity is valued at: $14606678.37
# Cash Position: $0.00
# Portfolio Total: $14606678.37
# Portfolio appreciates by 46.1 %
#
#
# Equity is valued at: $21463938.74
# Cash Position: $0.00
# Portfolio Total: $21463938.74
# Portfolio appreciates by 114.6 %
#
#
# Equity is valued at: $16014800.71
# Cash Position: $0.00
# Portfolio Total: $16014800.71
# Portfolio appreciates by 60.1 %
#
#
# Equity is valued at: $12763594.00
# Cash Position: $0.00
# Portfolio Total: $12763594.00
# Portfolio appreciates by 27.6 %
#
#
# Equity is valued at: $18624277.06
# Cash Position: $0.00
# Portfolio Total: $18624277.06
# Portfolio appreciates by 86.2 %
#
#
# Equity is valued at: $14455804.55
# Cash Position: $0.00
# Portfolio Total: $14455804.55
# Portfolio appreciates by 44.6 %
#
#
# Equity is valued at: $17856431.37
# Cash Position: $0.00
# Portfolio Total: $17856431.37
# Portfolio appreciates by 78.6 %
#
#
# Equity is valued at: $13772131.47
# Cash Position: $0.00
# Portfolio Total: $13772131.47
# Portfolio appreciates by 37.7 %
#
#
# Equity is valued at: $16385693.33
# Cash Position: $0.00
# Portfolio Total: $16385693.33
# Portfolio appreciates by 63.9 %
#
#
# Equity is valued at: $17526376.54
# Cash Position: $0.00
# Portfolio Total: $17526376.54
# Portfolio appreciates by 75.3 %
#
#
# Equity is valued at: $15173839.50
# Cash Position: $0.00
# Portfolio Total: $15173839.50
# Portfolio appreciates by 51.7 %
#
#
# Equity is valued at: $14072390.42
# Cash Position: $0.00
# Portfolio Total: $14072390.42
# Portfolio appreciates by 40.7 %
#
#
# Equity is valued at: $13711755.80
# Cash Position: $0.00
# Portfolio Total: $13711755.80
# Portfolio appreciates by 37.1 %
#
#
# Equity is valued at: $28859501.83
# Cash Position: $0.00
# Portfolio Total: $28859501.83
# Portfolio appreciates by 188.6 %
#
#
# Equity is valued at: $11731533.93
# Cash Position: $0.00
# Portfolio Total: $11731533.93
# Portfolio appreciates by 17.3 %
# Equity is valued at: $13711217.52
# Cash Position: $0.00
# Portfolio Total: $13711217.52
# Portfolio appreciates by 37.1 %
#
#
# Equity is valued at: $13407769.76
# Cash Position: $0.00
# Portfolio Total: $13407769.76
# Portfolio appreciates by 34.1 %
#
#
# Equity is valued at: $13173795.61
# Cash Position: $0.00
# Portfolio Total: $13173795.61
# Portfolio appreciates by 31.7 %
#
#
# Equity is valued at: $18859240.27
# Cash Position: $0.00
# Portfolio Total: $18859240.27
# Portfolio appreciates by 88.6 %
#
#
# Equity is valued at: $15709476.08
# Equity is valued at: $15022832.41
# Cash Position: $0.00
# Portfolio Total: $15022832.41
# Portfolio appreciates by 50.2 %
#
#
# Equity is valued at: $17651162.03
# Cash Position: $0.00
# Portfolio Total: $17651162.03
# Portfolio appreciates by 76.5 %
#
#
# Equity is valued at: $23475547.00
# Cash Position: $0.00
# Portfolio Total: $23475547.00
# Portfolio appreciates by 134.8 %
#
#
# Equity is valued at: $15735921.60
# Cash Position: $0.00
# Portfolio Total: $15735921.60
# Portfolio appreciates by 57.4 %
#
#
# Equity is valued at: $11917371.14
# Cash Position: $0.00
# Portfolio Total: $11917371.14
# Portfolio appreciates by 19.2 %
#
#
# Equity is valued at: $17802202.86
# Cash Position: $0.00
# Portfolio Total: $17802202.86
# Portfolio appreciates by 78.0 %
#
#
# Equity is valued at: $16907998.64
# Cash Position: $0.00
# Portfolio Total: $16907998.64
# Portfolio appreciates by 69.1 %
#
#
# Equity is valued at: $16379422.43
# Cash Position: $0.00
# Portfolio Total: $16379422.43
# Portfolio appreciates by 63.8 %
#
#
# Equity is valued at: $15952697.83
# Cash Position: $0.00
# Portfolio Total: $15952697.83
# Portfolio appreciates by 59.5 %
#
#
# Equity is valued at: $15142357.76
# Cash Position: $0.00
# Portfolio Total: $15142357.76
# Portfolio appreciates by 51.4 %
#
#
# Equity is valued at: $15401250.33
# Cash Position: $0.00
# Portfolio Total: $15401250.33
# Portfolio appreciates by 54.0 %
#
#
# Equity is valued at: $15244809.95
# Cash Position: $0.00
# Portfolio Total: $15244809.95
# Portfolio appreciates by 52.4 %
#
#
# Equity is valued at: $28896452.29
# Cash Position: $0.00
# Portfolio Total: $28896452.29
# Portfolio appreciates by 189.0 %
#
#
# Equity is valued at: $17577350.26
# Cash Position: $0.00
# Portfolio Total: $17577350.26
# Portfolio appreciates by 75.8 %
#
#
# Equity is valued at: $26530004.86
# Cash Position: $0.00
# Portfolio Total: $26530004.86
# Portfolio appreciates by 165.3 %
#
#
# Equity is valued at: $25620457.91
# Cash Position: $0.00
# Portfolio Total: $25620457.91
# Portfolio appreciates by 156.2 %
#
#
# Equity is valued at: $18498291.23
# Cash Position: $0.00
# Portfolio Total: $18498291.23
# Portfolio appreciates by 85.0 %
#
#
# Equity is valued at: $15316445.10
# Cash Position: $0.00
# Portfolio Total: $15316445.10
# Portfolio appreciates by 53.2 %
#
#
# Equity is valued at: $15753607.60
# Cash Position: $0.00
# Portfolio Total: $15753607.60
# Portfolio appreciates by 57.5 %
#
#
# Equity is valued at: $14580904.04
# Cash Position: $0.00
# Portfolio Total: $14580904.04
# Portfolio appreciates by 45.8 %
#
#
# Equity is valued at: $14413240.73
# Cash Position: $0.00
# Portfolio Total: $14413240.73
# Portfolio appreciates by 44.1 %
#
#
# Equity is valued at: $20243636.44
# Cash Position: $0.00
# Portfolio Total: $20243636.44
# Portfolio appreciates by 102.4 %
#
#
# Equity is valued at: $13946780.60
# Cash Position: $0.00
# Portfolio Total: $13946780.60
# Portfolio appreciates by 39.5 %
#
#
# Equity is valued at: $15197181.14
# Cash Position: $0.00
# Portfolio Total: $15197181.14
# Portfolio appreciates by 52.0 %
#
#
# Equity is valued at: $11804873.99
# Cash Position: $0.00
# Portfolio Total: $11804873.99
# Portfolio appreciates by 18.0 %
#
#
# Equity is valued at: $15477051.95
# Cash Position: $0.00
# Portfolio Total: $15477051.95
# Portfolio appreciates by 54.8 %
#
#
# Equity is valued at: $18925624.96
# Cash Position: $0.00
# Portfolio Total: $18925624.96
# Portfolio appreciates by 89.3 %
#
#
# Equity is valued at: $14900531.25
# Cash Position: $0.00
# Portfolio Total: $14900531.25
# Portfolio appreciates by 49.0 %
#
#
# Equity is valued at: $13717424.43
# Cash Position: $0.00
# Portfolio Total: $13717424.43
# Portfolio appreciates by 37.2 %
#
#
# Equity is valued at: $13634857.85
# Cash Position: $0.00
# Portfolio Total: $13634857.85
# Portfolio appreciates by 36.3 %
#
#
# Equity is valued at: $12795821.44
# Cash Position: $0.00
# Portfolio Total: $12795821.44
# Portfolio appreciates by 28.0 %
#
#
# Equity is valued at: $19652351.89
# Cash Position: $0.00
# Portfolio Total: $19652351.89
# Portfolio appreciates by 96.5 %
#
#
# Equity is valued at: $17496473.95
# Cash Position: $0.00
# Portfolio Total: $17496473.95
# Portfolio appreciates by 75.0 %
#
#
# Equity is valued at: $14221604.94
# Cash Position: $0.00
# Portfolio Total: $14221604.94
# Portfolio appreciates by 42.2 %
#
#
# Equity is valued at: $17372313.87
# Cash Position: $0.00
# Portfolio Total: $17372313.87
# Portfolio appreciates by 73.7 %
#
#
# Equity is valued at: $19551216.06
# Cash Position: $0.00
# Portfolio Total: $19551216.06
# Portfolio appreciates by 95.5 %
#
#
# Equity is valued at: $15795229.20
# Cash Position: $0.00
# Portfolio Total: $15795229.20
# Portfolio appreciates by 58.0 %
#
#
# Equity is valued at: $22076035.44
# Cash Position: $0.00
# Portfolio Total: $22076035.44
# Portfolio appreciates by 120.8 %
#
#
# Equity is valued at: $15221703.92
# Cash Position: $0.00
# Portfolio Total: $15221703.92
# Portfolio appreciates by 52.2 %
#
#
# Equity is valued at: $40019570.78
# Cash Position: $0.00
# Portfolio Total: $40019570.78
# Portfolio appreciates by 300.2 %
#
#
# Equity is valued at: $18723858.64
# Cash Position: $0.00
# Portfolio Total: $18723858.64
# Portfolio appreciates by 87.2 %
#
#
# Equity is valued at: $19153789.88
# Cash Position: $0.00
# Portfolio Total: $19153789.88
# Portfolio appreciates by 91.5 %
#
#
# Equity is valued at: $18287946.39
# Cash Position: $0.00
# Portfolio Total: $18287946.39
# Portfolio appreciates by 82.9 %
#
#
# Equity is valued at: $14195311.59
# Cash Position: $0.00
# Portfolio Total: $14195311.59
# Portfolio appreciates by 42.0 %
#
#
# Equity is valued at: $13057508.73
# Cash Position: $0.00
# Portfolio Total: $13057508.73
# Portfolio appreciates by 30.6 %
#
#
# Equity is valued at: $18171100.16
# Cash Position: $0.00
# Portfolio Total: $18171100.16
# Portfolio appreciates by 81.7 %
#
#
# Equity is valued at: $16414090.46
# Cash Position: $0.00
# Portfolio Total: $16414090.46
#
# Equity is valued at: $15329405.91
# Cash Position: $0.00
# Portfolio Total: $15329405.91
# Portfolio appreciates by 53.3 %
#
#
# Equity is valued at: $15501858.50
# Cash Position: $0.00
# Portfolio Total: $15501858.50
# Portfolio appreciates by 55.0 %
#
#
# Equity is valued at: $15519755.51
# Cash Position: $0.00
# Portfolio Total: $15519755.51
# Portfolio appreciates by 55.2 %
#
#
# Equity is valued at: $19862207.06
# Cash Position: $0.00
# Portfolio Total: $19862207.06
# Portfolio appreciates by 98.6 %
#
#
# Equity is valued at: $17793226.76
# Cash Position: $0.00
# Portfolio Total: $17793226.76
# Portfolio appreciates by 77.9 %
#
#
# Equity is valued at: $14999803.77
# Cash Position: $0.00
# Portfolio Total: $14999803.77
# Portfolio appreciates by 50.0 %
#
#
# Equity is valued at: $23104716.17
# Cash Position: $0.00
# Portfolio Total: $23104716.17
# Portfolio appreciates by 131.0 %
#
#
# Equity is valued at: $14296686.75
# Cash Position: $0.00
# Portfolio Total: $14296686.75
# Portfolio appreciates by 43.0 %
#
#
# Equity is valued at: $18496810.19
# Cash Position: $0.00
# Portfolio Total: $18496810.19
# Portfolio appreciates by 85.0 %
#
#
# Equity is valued at: $18244206.45
# Cash Position: $0.00
# Portfolio Total: $18244206.45
# Portfolio appreciates by 82.4 %
#
#
# Equity is valued at: $14811493.07
# Cash Position: $0.00
# Portfolio Total: $14811493.07
# Portfolio appreciates by 48.1 %
#
#
# Equity is valued at: $23412303.91
# Cash Position: $0.00
# Portfolio Total: $23412303.91
# Portfolio appreciates by 134.1 %
#
#
# Equity is valued at: $13148930.57
# Cash Position: $0.00
# Portfolio Total: $13148930.57
# Portfolio appreciates by 31.5 %
#
#
# Equity is valued at: $13079193.50
# Cash Position: $0.00
# Portfolio Total: $13079193.50
# Portfolio appreciates by 30.8 %
#
#
# Equity is valued at: $15068328.18
# Cash Position: $0.00
# Portfolio Total: $15068328.18
# Portfolio appreciates by 50.7 %
#
#
# Equity is valued at: $13758203.87
# Cash Position: $0.00
# Portfolio Total: $13758203.87
# Portfolio appreciates by 37.6 %
#
#
# Equity is valued at: $14152285.10
# Cash Position: $0.00
# Portfolio Total: $14152285.10
# Portfolio appreciates by 41.5 %
#
#
# Equity is valued at: $28166193.07
# Cash Position: $0.00
# Portfolio Total: $28166193.07
# Portfolio appreciates by 181.7 %
#
#
# Equity is valued at: $17974101.22
# Cash Position: $0.00
# Portfolio Total: $17974101.22
# Portfolio appreciates by 79.7 %
#
#
# Equity is valued at: $18101344.25
# Cash Position: $0.00
# Portfolio Total: $18101344.25
# Portfolio appreciates by 81.0 %
#
#
# Equity is valued at: $26091694.55
# Cash Position: $0.00
# Portfolio Total: $26091694.55
# Portfolio appreciates by 160.9 %
#
#
# Equity is valued at: $18429009.08
# Cash Position: $0.00
# Portfolio Total: $18429009.08
# Portfolio appreciates by 84.3 %
#
#
# Equity is valued at: $16738526.71
# Cash Position: $0.00
# Portfolio Total: $16738526.71
# Portfolio appreciates by 67.4 %
#
#
# Equity is valued at: $13174153.77
# Cash Position: $0.00
# Portfolio Total: $13174153.77
# Portfolio appreciates by 31.7 %
#
#
# Equity is valued at: $20103246.95
# Cash Position: $0.00
# Portfolio Total: $20103246.95
# Portfolio appreciates by 101.0 %
#
#
# Equity is valued at: $11614666.96
# Cash Position: $0.00
# Portfolio Total: $11614666.96
# Portfolio appreciates by 16.1 %
#
#
# Equity is valued at: $15474434.81
# Cash Position: $0.00
# Portfolio Total: $15474434.81
# Portfolio appreciates by 54.7 %
#
#
# Equity is valued at: $18669244.15
# Cash Position: $0.00
# Portfolio Total: $18669244.15
# Portfolio appreciates by 86.7 %
#
#
# Equity is valued at: $11913657.65
# Cash Position: $0.00
# Portfolio Total: $11913657.65
# Portfolio appreciates by 19.1 %
#
#
# Equity is valued at: $30059394.98
# Cash Position: $0.00
# Portfolio Total: $30059394.98
# Portfolio appreciates by 200.6 %
#
#
# Equity is valued at: $15193346.33
# Cash Position: $0.00
# Portfolio Total: $15193346.33
# Portfolio appreciates by 51.9 %
#
#
# Equity is valued at: $18178243.05
# Cash Position: $0.00
# Portfolio Total: $18178243.05
# Portfolio appreciates by 81.8 %
#
#
# Equity is valued at: $14593104.28
# Cash Position: $0.00
# Portfolio Total: $14593104.28
# Portfolio appreciates by 45.9 %
#
#
# Equity is valued at: $19860545.78
# Cash Position: $0.00
# Portfolio Total: $19860545.78
# Portfolio appreciates by 98.6 %
#
#
# Equity is valued at: $20251523.21
# Cash Position: $0.00
# Portfolio Total: $20251523.21
# Portfolio appreciates by 102.5 %
#
#
# Equity is valued at: $14569719.15
# Cash Position: $0.00
# Portfolio Total: $14569719.15
# Portfolio appreciates by 45.7 %
#
#
# Equity is valued at: $19162038.57
# Cash Position: $0.00
# Portfolio Total: $19162038.57
# Portfolio appreciates by 91.6 %
#
#
# Equity is valued at: $26861393.32
# Cash Position: $0.00
# Portfolio Total: $26861393.32
# Portfolio appreciates by 168.6 %
#
#
# Equity is valued at: $12949991.69
# Cash Position: $0.00
# Portfolio Total: $12949991.69
# Portfolio appreciates by 29.5 %
#
#
# Equity is valued at: $24633338.04
# Cash Position: $0.00
# Portfolio Total: $24633338.04
# Portfolio appreciates by 146.3 %
#
#
# Equity is valued at: $15776149.20
# Cash Position: $0.00
# Portfolio Total: $15776149.20
# Portfolio appreciates by 57.8 %
#
#
# Equity is valued at: $18590384.34
# Cash Position: $0.00
# Portfolio Total: $18590384.34
# Portfolio appreciates by 85.9 %
#
#
# Equity is valued at: $15866517.33
# Cash Position: $0.00
# Portfolio Total: $15866517.33
# Portfolio appreciates by 58.7 %
#
#
# Equity is valued at: $18699145.65
# Cash Position: $0.00
# Portfolio Total: $18699145.65
# Portfolio appreciates by 87.0 %
#
#
# Equity is valued at: $14511840.08
# Cash Position: $0.00
# Portfolio Total: $14511840.08
# Portfolio appreciates by 45.1 %
#
#
# Equity is valued at: $20825927.23
# Cash Position: $0.00
# Portfolio Total: $20825927.23
# Portfolio appreciates by 108.3 %
#
#
# Equity is valued at: $16810163.82
# Cash Position: $0.00
# Portfolio Total: $16810163.82
#
#
# Equity is valued at: $14089083.91
# Cash Position: $0.00
# Portfolio Total: $14089083.91
# Portfolio appreciates by 40.9 %
#
#
# Equity is valued at: $26217527.54
# Cash Position: $0.00
# Portfolio Total: $26217527.54
# Portfolio appreciates by 162.2 %
#
#
# Equity is valued at: $18695952.83
# Cash Position: $0.00
# Portfolio Total: $18695952.83
# Portfolio appreciates by 87.0 %
#
#
# Equity is valued at: $14169931.20
# Cash Position: $0.00
# Portfolio Total: $14169931.20
# Portfolio appreciates by 41.7 %
#
#
# Equity is valued at: $15081132.10
# Cash Position: $0.00
# Portfolio Total: $15081132.10
# Portfolio appreciates by 50.8 %
#
#
# Equity is valued at: $11448621.10
# Cash Position: $0.00
# Portfolio Total: $11448621.10
# Portfolio appreciates by 14.5 %
#
#
# Equity is valued at: $13452337.04
# Cash Position: $0.00
# Portfolio Total: $13452337.04
# Portfolio appreciates by 34.5 %
#
#
# Equity is valued at: $21723962.79
# Cash Position: $0.00
# Portfolio Total: $21723962.79
# Portfolio appreciates by 117.2 %
#
#
# Equity is valued at: $17214357.82
# Cash Position: $0.00
# Portfolio Total: $17214357.82
# Portfolio appreciates by 72.1 %
#
#
# Equity is valued at: $16512168.17
# Cash Position: $0.00
# Portfolio Total: $16512168.17
# Portfolio appreciates by 65.1 %
#
#
# Equity is valued at: $18767072.72
# Cash Position: $0.00
# Portfolio Total: $18767072.72
# Portfolio appreciates by 87.7 %
#
#
# Equity is valued at: $12818743.65
# Cash Position: $0.00
# Portfolio Total: $12818743.65
# Portfolio appreciates by 28.2 %
#
#
# Equity is valued at: $14722294.13
# Cash Position: $0.00
# Portfolio Total: $14722294.13
# Portfolio appreciates by 47.2 %
#
#
# Equity is valued at: $18481029.78
# Cash Position: $0.00
# Portfolio Total: $18481029.78
# Portfolio appreciates by 84.8 %
#
#
# Equity is valued at: $12156910.59
# Cash Position: $0.00
# Portfolio Total: $12156910.59
# Portfolio appreciates by 21.6 %
#
#
# Equity is valued at: $23706462.44
# Cash Position: $0.00
# Portfolio Total: $23706462.44
# Portfolio appreciates by 137.1 %
#
#
# Equity is valued at: $12422176.34
# Cash Position: $0.00
# Portfolio Total: $12422176.34
# Portfolio appreciates by 24.2 %
#
#
# Equity is valued at: $13517626.79
# Cash Position: $0.00
# Portfolio Total: $13517626.79
# Portfolio appreciates by 35.2 %
#
#
# Equity is valued at: $15313528.95
# Cash Position: $0.00
# Portfolio Total: $15313528.95
# Portfolio appreciates by 53.1 %
#
#
# Equity is valued at: $16229051.17
# Cash Position: $0.00
# Portfolio Total: $16229051.17
# Portfolio appreciates by 62.3 %
#
#
# Equity is valued at: $12906273.15
# Cash Position: $0.00
# Portfolio Total: $12906273.15
# Portfolio appreciates by 29.1 %
#
#
# Equity is valued at: $27176503.44
# Cash Position: $0.00
# Portfolio Total: $27176503.44
# Portfolio appreciates by 171.8 %
#
#
# Equity is valued at: $15681474.51
# Cash Position: $0.00
# Portfolio Total: $15681474.51
# Portfolio appreciates by 56.8 %
#
#
# Equity is valued at: $26352001.06
# Portfolio Total: $22529762.73
# Portfolio appreciates by 125.3 %
#
#
# Equity is valued at: $14945231.35
# Cash Position: $0.00
# Portfolio Total: $14945231.35
# Portfolio appreciates by 49.5 %
#
#
# Equity is valued at: $16953523.71
# Cash Position: $0.00
# Portfolio Total: $16953523.71
# ...
#
#
# Equity is valued at: $18857516.62
# Cash Position: $0.00
# Portfolio Total: $18857516.62
# Portfolio appreciates by 88.6 %
#
#
# Equity is valued at: $12100799.32
# Cash Position: $0.00
# Portfolio Total: $12100799.32
# Portfolio appreciates by 21.0 %
#
#
# Equity is valued at: $15907935.86
# Cash Position: $0.00
# Portfolio Total: $15907935.86
# Portfolio appreciates by 59.1 %
#
#
# Equity is valued at: $13564473.94
# Cash Position: $0.00
# Portfolio Total: $13564473.94
# Portfolio appreciates by 35.6 %
#
#
# Equity is valued at: $16629315.53
# Cash Position: $0.00
# Portfolio Total: $16629315.53
# Portfolio appreciates by 66.3 %
#
#
# Equity is valued at: $18589647.93
# Cash Position: $0.00
# Portfolio Total: $18589647.93
# Portfolio appreciates by 85.9 %
#
#
# Equity is valued at: $16073212.81
# Cash Position: $0.00
# Portfolio Total: $16073212.81
# Portfolio appreciates by 60.7 %
#
#
# Equity is valued at: $22603517.72
# Cash Position: $0.00
# Portfolio Total: $22603517.72
# Portfolio appreciates by 126.0 %
#
#
# Equity is valued at: $18070417.34
# Cash Position: $0.00
# Portfolio Total: $18070417.34
# Portfolio appreciates by 80.7 %
#
#
# Equity is valued at: $14474662.84
# Cash Position: $0.00
# Portfolio Total: $14474662.84
# Portfolio appreciates by 44.7 %
#
#
# Equity is valued at: $22451209.16
# Cash Position: $0.00
# Portfolio Total: $22451209.16
# Portfolio appreciates by 124.5 %
#
#
# Equity is valued at: $16836451.08
# Cash Position: $0.00
# Portfolio Total: $16836451.08
# Portfolio appreciates by 68.4 %
#
#
# Equity is valued at: $17552017.54
# Cash Position: $0.00
# Portfolio Total: $17552017.54
# Portfolio appreciates by 75.5 %
#
#
# Equity is valued at: $26821699.43
# Cash Position: $0.00
# Portfolio Total: $26821699.43
# Portfolio appreciates by 168.2 %
#
#
# Equity is valued at: $18672011.51
# Cash Position: $0.00
# Portfolio Total: $18672011.51
# Portfolio appreciates by 86.7 %
#
#
# Equity is valued at: $13046091.73
# Cash Position: $0.00
# Portfolio Total: $13046091.73
# Portfolio appreciates by 30.5 %
#
#
# Equity is valued at: $22003445.01
# Cash Position: $0.00
# Portfolio Total: $22003445.01
# Portfolio appreciates by 120.0 %
#
#
# Equity is valued at: $19724432.26
# Cash Position: $0.00
# Portfolio Total: $19724432.26
# Portfolio appreciates by 97.2 %
#
#
# Equity is valued at: $17306184.53
# Cash Position: $0.00
# Portfolio Total: $17306184.53
# Portfolio appreciates by 73.1 %
#
#
# Equity is valued at: $12923381.55
# Cash Position: $0.00
# Portfolio Total: $12923381.55
# Portfolio appreciates by 29.2 %
#
#
# Equity is valued at: $23788148.96
# Cash Position: $0.00
# Portfolio Total: $23788148.96
# Portfolio appreciates by 137.9 %
#
#
# Portfolio appreciates by 55.9 %
#
#
# Equity is valued at: $24257328.25
# Cash Position: $0.00
# Portfolio Total: $24257328.25
# Portfolio appreciates by 142.6 %
#
#
# Equity is valued at: $16522835.76
# Cash Position: $0.00
# Portfolio Total: $16522835.76
# Portfolio appreciates by 65.2 %
#
#
# Equity is valued at: $26558911.08
# Cash Position: $0.00
# Portfolio Total: $26558911.08
# Portfolio appreciates by 165.6 %
#
#
# Equity is valued at: $15122599.84
# Cash Position: $0.00
# Portfolio Total: $15122599.84
# Portfolio appreciates by 51.2 %
#
#
# Equity is valued at: $23972401.78
# Cash Position: $0.00
# Portfolio Total: $23972401.78
# Portfolio appreciates by 139.7 %
#
#
# Equity is valued at: $18025865.40
# Cash Position: $0.00
# Portfolio Total: $18025865.40
# Portfolio appreciates by 80.3 %
#
#
# Equity is valued at: $13224768.79
# Cash Position: $0.00
# Portfolio Total: $13224768.79
# Portfolio appreciates by 32.2 %
#
#
# Equity is valued at: $13216939.96
# Cash Position: $0.00
# Portfolio Total: $13216939.96
# Portfolio appreciates by 32.2 %
#
#
# Equity is valued at: $25050623.10
# Cash Position: $0.00
# Portfolio Total: $25050623.10
# Portfolio appreciates by 150.5 %
#
#
# Equity is valued at: $15118522.88
# Cash Position: $0.00
# Portfolio Total: $15118522.88
# Portfolio appreciates by 51.2 %
#
#
# Equity is valued at: $14987525.34
# Cash Position: $0.00
# Portfolio Total: $14987525.34
# Portfolio appreciates by 49.9 %
#
#
# Equity is valued at: $22220927.46
# Cash Position: $0.00
# Portfolio Total: $22220927.46
# Portfolio appreciates by 122.2 %
#
#
# Equity is valued at: $17405035.22
# Cash Position: $0.00
# Portfolio Total: $17405035.22
# Portfolio appreciates by 74.1 %
#
#
# Equity is valued at: $21848092.14
# Cash Position: $0.00
# Portfolio Total: $21848092.14
# Portfolio appreciates by 118.5 %
#
#
# Equity is valued at: $15188037.18
# Cash Position: $0.00
# Portfolio Total: $15188037.18
# Portfolio appreciates by 51.9 %
#
#
# Equity is valued at: $14029468.17
# Cash Position: $0.00
# Portfolio Total: $14029468.17
# Portfolio appreciates by 40.3 %
#
#
# Equity is valued at: $15126178.11
# Cash Position: $0.00
# Portfolio Total: $15126178.11
# Portfolio appreciates by 51.3 %
#
#
# Equity is valued at: $16253125.64
# Cash Position: $0.00
# Portfolio Total: $16253125.64
# Portfolio appreciates by 62.5 %
#
#
# Equity is valued at: $14205172.52
# Cash Position: $0.00
# Portfolio Total: $14205172.52
# Portfolio appreciates by 42.1 %
#
#
# Equity is valued at: $26036861.94
# Cash Position: $0.00
# Portfolio Total: $26036861.94
# Portfolio appreciates by 160.4 %
#
#
# Equity is valued at: $21073902.85
# Cash Position: $0.00
# Portfolio Total: $21073902.85
# Portfolio appreciates by 110.7 %
#
#
# Equity is valued at: $24601403.79
# Cash Position: $0.00
# Portfolio Total: $24601403.79
# Portfolio appreciates by 146.0 %
#
#
# Equity is valued at: $30212807.10
# Cash Position: $0.00
# Portfolio Total: $30212807.10
# Portfolio appreciates by 202.1 %
#
#
# Equity is valued at: $20574404.18
# Cash Position: $0.00
# Portfolio Total: $20574404.18
# Portfolio appreciates by 105.7 %
#
#
# Equity is valued at: $14706198.56
# Cash Position: $0.00
# Portfolio Total: $14706198.56
# Portfolio appreciates by 47.1 %
# Equity is valued at: $14804167.97
# Cash Position: $0.00
# Portfolio Total: $14804167.97
# Portfolio appreciates by 48.0 %
#
#
# Equity is valued at: $24378598.82
# Cash Position: $0.00
# Portfolio Total: $24378598.82
# Portfolio appreciates by 143.8 %
#
#
# Equity is valued at: $26123244.20
# Cash Position: $0.00
# Portfolio Total: $26123244.20
# Portfolio appreciates by 161.2 %
#
#
# Equity is valued at: $18237527.34
# Cash Position: $0.00
# Portfolio Total: $18237527.34
# Portfolio appreciates by 82.4 %
#
#
# Equity is valued at: $12230199.66
# Cash Position: $0.00
# Portfolio Total: $12230199.66
# Portfolio appreciates by 22.3 %
#
#
# Equity is valued at: $12914615.11
# Cash Position: $0.00
# Portfolio Total: $12914615.11
# Portfolio appreciates by 29.1 %
#
#
# Equity is valued at: $14082544.67
# Cash Position: $0.00
# Portfolio Total: $14082544.67
# Portfolio appreciates by 40.8 %
#
#
# Equity is valued at: $12650834.19
# Cash Position: $0.00
# Portfolio Total: $12650834.19
# Portfolio appreciates by 26.5 %
#
#
# Equity is valued at: $18829111.56
# Cash Position: $0.00
# Portfolio Total: $18829111.56
# Portfolio appreciates by 88.3 %
#
#
# Equity is valued at: $18378351.29
# Cash Position: $0.00
# Portfolio Total: $18378351.29
# Portfolio appreciates by 83.8 %
#
#
# Equity is valued at: $34735702.00
# Cash Position: $0.00
# Portfolio Total: $34735702.00
# Portfolio appreciates by 247.4 %
#
#
# Equity is valued at: $20725637.03
# Cash Position: $0.00
# Portfolio Total: $20725637.03
# Portfolio appreciates by 107.3 %
#
#
# Equity is valued at: $12718167.47
# Cash Position: $0.00
# Portfolio Total: $12718167.47
# Portfolio appreciates by 27.2 %
#
#
# Equity is valued at: $16000157.46
# Cash Position: $0.00
# Portfolio Total: $16000157.46
# Portfolio appreciates by 60.0 %
#
#
# Equity is valued at: $16422681.49
# Cash Position: $0.00
# Portfolio Total: $16422681.49
# Portfolio appreciates by 64.2 %
#
#
# Equity is valued at: $14153167.54
# Cash Position: $0.00
# Portfolio Total: $14153167.54
# Portfolio appreciates by 41.5 %
#
#
# Equity is valued at: $15036233.24
# Cash Position: $0.00
# Portfolio Total: $15036233.24
# Portfolio appreciates by 50.4 %
#
#
# Equity is valued at: $9986073.64
# Cash Position: $0.00
# Portfolio Total: $9986073.64
# Portfolio appreciates by -0.1 %
#
#
# Equity is valued at: $21826219.60
# Cash Position: $0.00
# Portfolio Total: $21826219.60
# Portfolio appreciates by 118.3 %
#
#
# Equity is valued at: $28545790.63
# Cash Position: $0.00
# Portfolio Total: $28545790.63
# Portfolio appreciates by 185.5 %
#
#
# Equity is valued at: $21268283.83
# Cash Position: $0.00
# Portfolio Total: $21268283.83
# Portfolio appreciates by 112.7 %
#
#
# Equity is valued at: $22019410.50
# Cash Position: $0.00
# Portfolio Total: $22019410.50
# Portfolio appreciates by 120.2 %
#
#
# Equity is valued at: $11144594.08
# Cash Position: $0.00
# Portfolio Total: $11144594.08
# Portfolio appreciates by 11.4 %
#
#
# Equity is valued at: $17638176.75
# Cash Position: $0.00
# Portfolio Total: $17638176.75
# Portfolio appreciates by 76.4 %
#
#
# Equity is valued at: $13068233.06
# Cash Position: $0.00
# Portfolio Total: $13068233.06
# Portfolio appreciates by 30.7 %
#
#
# Equity is valued at: $13919104.35
# Cash Position: $0.00
# Portfolio Total: $13919104.35
# Portfolio appreciates by 39.2 %
#
#
# Equity is valued at: $18050601.67
# Cash Position: $0.00
# Portfolio Total: $18050601.67
# Portfolio appreciates by 80.5 %
#
#
# Equity is valued at: $22679513.63
# Cash Position: $0.00
# Portfolio Total: $22679513.63
# Portfolio appreciates by 126.8 %
#
#
# Equity is valued at: $19110820.14
# Cash Position: $0.00
# Portfolio Total: $19110820.14
# Portfolio appreciates by 91.1 %
#
#
# Equity is valued at: $13084082.89
# Cash Position: $0.00
# Portfolio Total: $13084082.89
# Portfolio appreciates by 30.8 %
#
#
# Equity is valued at: $17255944.10
# Cash Position: $0.00
# Portfolio Total: $17255944.10
# Portfolio appreciates by 72.6 %
#
#
# Equity is valued at: $13480466.42
# Cash Position: $0.00
# Portfolio Total: $13480466.42
# Portfolio appreciates by 34.8 %
#
#
# Equity is valued at: $22173099.37
# Cash Position: $0.00
# Portfolio Total: $22173099.37
# Portfolio appreciates by 121.7 %
#
#
# Equity is valued at: $21281493.62
# Cash Position: $0.00
# Portfolio Total: $21281493.62
# Portfolio appreciates by 112.8 %
#
#
# Equity is valued at: $12377553.81
# Cash Position: $0.00
# Portfolio Total: $12377553.81
# Portfolio appreciates by 23.8 %
#
#
# Equity is valued at: $15649607.00
# Cash Position: $0.00
# Portfolio Total: $15649607.00
# Portfolio appreciates by 56.5 %
#
#
# Equity is valued at: $14951207.19
# Cash Position: $0.00
# Portfolio Total: $14951207.19
# Portfolio appreciates by 49.5 %
#
#
# Equity is valued at: $18208323.06
# Cash Position: $0.00
# Portfolio Total: $18208323.06
# Portfolio appreciates by 82.1 %
#
#
# Equity is valued at: $15328520.21
# Cash Position: $0.00
# Portfolio Total: $15328520.21
# Portfolio appreciates by 53.3 %
#
#
# Equity is valued at: $18366157.12
# Cash Position: $0.00
# Portfolio Total: $18366157.12
# Portfolio appreciates by 83.7 %
#
#
# Equity is valued at: $15449449.31
# Cash Position: $0.00
# Portfolio Total: $15449449.31
# Portfolio appreciates by 54.5 %

# %%
import statistics

print ("Strategy Three Return - mean:{:.1f}%, std:{:.1f}%".format(statistics.mean(returns),statistics.stdev(returns)))
plt.figure(figsize=(10, 6))
num_bins = 20
plt.hist(returns,num_bins)
plt.xlabel('Portfolio Return (%)')
plt.ylabel("Frequency")
plt.title("Strategy Three - Return Distribution")

plt.axvline(x=118.613, color="red", linestyle='--')
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# Strategy Three Return - mean:78.6%, std:49.5%
